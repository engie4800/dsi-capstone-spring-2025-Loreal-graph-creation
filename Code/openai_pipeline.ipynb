# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: openai in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from -r requirements.txt (line 1)) (1.69.0)
# Requirement already satisfied: graphdatascience in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from -r requirements.txt (line 2)) (1.12)
# Requirement already satisfied: retry==0.9.2 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from -r requirements.txt (line 3)) (0.9.2)
# Requirement already satisfied: langchain>=0.0.216 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from -r requirements.txt (line 4)) (0.3.21)
# Requirement already satisfied: streamlit==1.23.1 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from -r requirements.txt (line 5)) (1.23.1)
# Requirement already satisfied: streamlit-chat==0.0.2.2 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from -r requirements.txt (line 6)) (0.0.2.2)
# Requirement already satisfied: streamlit-chat-media==0.0.4 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from -r requirements.txt (line 7)) (0.0.4)
# Requirement already satisfied: numpy in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from -r requirements.txt (line 8)) (1.26.4)
# Requirement already satisfied: pandas in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from -r requirements.txt (line 9)) (2.2.3)
# Requirement already satisfied: plotly==5.15.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from -r requirements.txt (line 10)) (5.15.0)
# Requirement already satisfied: altair<5 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from -r requirements.txt (line 11)) (4.2.2)
# Requirement already satisfied: python-dotenv==1.0.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from -r requirements.txt (line 12)) (1.0.0)
# Requirement already satisfied: decorator>=3.4.2 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from retry==0.9.2->-r requirements.txt (line 3)) (5.2.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from retry==0.9.2->-r requirements.txt (line 3)) (1.11.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (8.1.8)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (6.11.0)
# Requirement already satisfied: packaging<24,>=14.1 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (23.2)
# Requirement already satisfied: pillow<10,>=6.2.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (9.5.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (4.25.6)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (16.1.0)
# Requirement already satisfied: pympler<2,>=0.9 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (1.1)
# Requirement already satisfied: python-dateutil<3,>=2 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: requests<3,>=2.4 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: rich<14,>=10.11.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (13.9.4)
# Requirement already satisfied: tenacity<9,>=8.0.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (8.5.0)
# Requirement already satisfied: toml<2 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (4.13.0)
# Requirement already satisfied: tzlocal<5,>=1.1 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (4.3.1)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (0.34.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.1.dev5 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (6.4.2)
# Requirement already satisfied: watchdog in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (6.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from openai->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from openai->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from openai->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from openai->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from openai->-r requirements.txt (line 1)) (2.11.1)
# Requirement already satisfied: sniffio in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from openai->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from openai->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: multimethod<2.0,>=1.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from graphdatascience->-r requirements.txt (line 2)) (1.12)
# Requirement already satisfied: neo4j<6.0,>=4.4.12 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from graphdatascience->-r requirements.txt (line 2)) (5.28.1)
# Requirement already satisfied: textdistance<5.0,>=4.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from graphdatascience->-r requirements.txt (line 2)) (4.6.3)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from langchain>=0.0.216->-r requirements.txt (line 4)) (0.3.49)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from langchain>=0.0.216->-r requirements.txt (line 4)) (0.3.7)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from langchain>=0.0.216->-r requirements.txt (line 4)) (0.3.19)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from langchain>=0.0.216->-r requirements.txt (line 4)) (2.0.40)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from langchain>=0.0.216->-r requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from pandas->-r requirements.txt (line 9)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from pandas->-r requirements.txt (line 9)) (2025.2)
# Requirement already satisfied: entrypoints in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from altair<5->-r requirements.txt (line 11)) (0.4)
# Requirement already satisfied: jinja2 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from altair<5->-r requirements.txt (line 11)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from altair<5->-r requirements.txt (line 11)) (4.23.0)
# Requirement already satisfied: toolz in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from altair<5->-r requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: idna>=2.8 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: colorama in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from click<9,>=7.0->streamlit==1.23.1->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from gitpython!=3.1.19,<4,>=3->streamlit==1.23.1->-r requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: certifi in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 1)) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit==1.23.1->-r requirements.txt (line 5)) (3.21.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from jsonschema>=3.0->altair<5->-r requirements.txt (line 11)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from jsonschema>=3.0->altair<5->-r requirements.txt (line 11)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from jsonschema>=3.0->altair<5->-r requirements.txt (line 11)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from jsonschema>=3.0->altair<5->-r requirements.txt (line 11)) (0.24.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain>=0.0.216->-r requirements.txt (line 4)) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain>=0.0.216->-r requirements.txt (line 4)) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain>=0.0.216->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain>=0.0.216->-r requirements.txt (line 4)) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 1)) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from jinja2->altair<5->-r requirements.txt (line 11)) (3.0.2)
# Requirement already satisfied: pywin32>=226 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from pympler<2,>=0.9->streamlit==1.23.1->-r requirements.txt (line 5)) (310)
# Requirement already satisfied: six>=1.5 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from python-dateutil<3,>=2->streamlit==1.23.1->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from requests<3,>=2.4->streamlit==1.23.1->-r requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from requests<3,>=2.4->streamlit==1.23.1->-r requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from rich<14,>=10.11.0->streamlit==1.23.1->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from rich<14,>=10.11.0->streamlit==1.23.1->-r requirements.txt (line 5)) (2.19.1)
# Requirement already satisfied: greenlet>=1 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain>=0.0.216->-r requirements.txt (line 4)) (3.1.1)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from tzlocal<5,>=1.1->streamlit==1.23.1->-r requirements.txt (line 5)) (0.1.0.post0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3->streamlit==1.23.1->-r requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain>=0.0.216->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jiahe\onedrive\documents\capstone\dsi-capstone-spring-2025-loreal-graph-creation\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.11.0->streamlit==1.23.1->-r requirements.txt (line 5)) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import openai
from string import Template
import json
from neo4j import GraphDatabase
import glob
from timeit import default_timer as timer
from dotenv import load_dotenv
from time import sleep
import re
from pathlib import Path
import csv
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 from string import Template
#       4 import json
# ----> 5 from neo4j import GraphDatabase
#       6 import glob
#       7 from timeit import default_timer as timer
#
# File c:\Users\Jiahe\OneDrive\Documents\Capstone\dsi-capstone-spring-2025-Loreal-graph-creation\venv\Lib\site-packages\neo4j\__init__.py:28
#      18 from logging import getLogger as _getLogger
#      20 from ._api import (  # noqa: F401 dynamic attributes
#      21     NotificationCategory,
#      22     NotificationDisabledCategory,
#    (...)     26     RoutingControl,
#      27 )
# ---> 28 from ._async.driver import (
#      29     AsyncBoltDriver,
#      30     AsyncDriver,
#      31     AsyncGraphDatabase,
#      32     AsyncNeo4jDriver,
#      33 )
#      34 from ._async.work import (
#      35     AsyncManagedTransaction,
#      36     AsyncResult,
#      37     AsyncSession,
#      38     AsyncTransaction,
#      39 )
#      40 from ._conf import (  # noqa: F401 dynamic attribute
#      41     Config as _Config,
#      42     SessionConfig as _SessionConfig,
#    (...)     46     WorkspaceConfig as _WorkspaceConfig,
#      47 )
#
# File c:\Users\Jiahe\OneDrive\Documents\Capstone\dsi-capstone-spring-2025-Loreal-graph-creation\venv\Lib\site-packages\neo4j\_async\driver.py:96
#      90 from .bookmark_manager import (
#      91     AsyncNeo4jBookmarkManager,
#      92     TBmConsumer as _TBmConsumer,
#      93     TBmSupplier as _TBmSupplier,
#      94 )
#      95 from .config import AsyncPoolConfig
# ---> 96 from .work import (
#      97     AsyncManagedTransaction,
#      98     AsyncResult,
#      99     AsyncSession,
#     100 )
#     103 if t.TYPE_CHECKING:
#     104     import ssl
#
# File c:\Users\Jiahe\OneDrive\Documents\Capstone\dsi-capstone-spring-2025-Loreal-graph-creation\venv\Lib\site-packages\neo4j\_async\work\__init__.py:16
#       1 # Copyright (c) "Neo4j"
#       2 # Neo4j Sweden AB [https://neo4j.com]
#       3 #
#    (...)     13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
# ---> 16 from .result import (
#      17     AsyncResult,
#      18     EagerResult,
#      19 )
#      20 from .session import (
#      21     AsyncSession,
#      22     AsyncWorkspace,
#      23 )
#      24 from .transaction import (
#      25     AsyncManagedTransaction,
#      26     AsyncTransaction,
#      27     AsyncTransactionBase,
#      28 )
#
# File c:\Users\Jiahe\OneDrive\Documents\Capstone\dsi-capstone-spring-2025-Loreal-graph-creation\venv\Lib\site-packages\neo4j\_async\work\result.py:63
#      58 from ...warnings import (
#      59     Neo4jDeprecationWarning,
#      60     Neo4jWarning,
#      61 )
#      62 from .._debug import AsyncNonConcurrentMethodChecker
# ---> 63 from ..io import ConnectionErrorHandler
#      66 if t.TYPE_CHECKING:
#      67     import pandas  # type: ignore[import]
#
# File c:\Users\Jiahe\OneDrive\Documents\Capstone\dsi-capstone-spring-2025-Loreal-graph-creation\venv\Lib\site-packages\neo4j\_async\io\__init__.py:36
#      24 __all__ = [
#      25     "AcquisitionAuth",
#      26     "AcquisitionDatabase",
#    (...)     31     "check_supported_server_product",
#      32 ]
#      35 # [bolt-version-bump] search tag when changing bolt version support
# ---> 36 from . import (  # noqa - imports needed to register protocol handlers
#      37     _bolt3,
#      38     _bolt4,
#      39     _bolt5,
#      40 )
#      41 from ._bolt import AsyncBolt
#      42 from ._common import (
#      43     check_supported_server_product,
#      44     ConnectionErrorHandler,
#      45 )
#
# File c:\Users\Jiahe\OneDrive\Documents\Capstone\dsi-capstone-spring-2025-Loreal-graph-creation\venv\Lib\site-packages\neo4j\_async\io\_bolt3.py:37
#      25 from ...api import (
#      26     READ_ACCESS,
#      27     Version,
#      28 )
#      29 from ...exceptions import (
#      30     ConfigurationError,
#      31     DatabaseUnavailable,
#    (...)     35     ServiceUnavailable,
#      36 )
# ---> 37 from ._bolt import (
#      38     AsyncBolt,
#      39     ClientStateManagerBase,
#      40     ServerStateManagerBase,
#      41     tx_timeout_as_ms,
#      42 )
#      43 from ._common import (
#      44     check_supported_server_product,
#      45     CommitResponse,
#    (...)     48     Response,
#      49 )
#      52 if t.TYPE_CHECKING:
#
# File c:\Users\Jiahe\OneDrive\Documents\Capstone\dsi-capstone-spring-2025-Loreal-graph-creation\venv\Lib\site-packages\neo4j\_async\io\_bolt.py:28
#      26 from ..._async_compat.util import AsyncUtil
#      27 from ..._auth_management import to_auth_dict
# ---> 28 from ..._codec.hydration import (
#      29     HydrationHandlerABC,
#      30     v1 as hydration_v1,
#      31 )
#      32 from ..._codec.packstream import v1 as packstream_v1
#      33 from ..._deadline import Deadline
#
# File c:\Users\Jiahe\OneDrive\Documents\Capstone\dsi-capstone-spring-2025-Loreal-graph-creation\venv\Lib\site-packages\neo4j\_codec\hydration\v1\__init__.py:17
#       1 # Copyright (c) "Neo4j"
#       2 # Neo4j Sweden AB [https://neo4j.com]
#       3 #
#    (...)     13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
# ---> 17 from .hydration_handler import HydrationHandler
#      20 __all__ = [
#      21     "HydrationHandler",
#      22 ]
#
# File c:\Users\Jiahe\OneDrive\Documents\Capstone\dsi-capstone-spring-2025-Loreal-graph-creation\venv\Lib\site-packages\neo4j\_codec\hydration\v1\hydration_handler.py:24
#       1 # Copyright (c) "Neo4j"
#       2 # Neo4j Sweden AB [https://neo4j.com]
#       3 #
#    (...)     13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
#      17 from datetime import (
#      18     date,
#      19     datetime,
#      20     time,
#      21     timedelta,
#      22 )
# ---> 24 from ...._optional_deps import (
#      25     np,
#      26     pd,
#      27 )
#      28 from ....graph import (
#      29     Graph,
#      30     Node,
#      31     Path,
#      32 )
#      33 from ....spatial import (
#      34     CartesianPoint,
#      35     Point,
#      36     WGS84Point,
#      37 )
#
# File c:\Users\Jiahe\OneDrive\Documents\Capstone\dsi-capstone-spring-2025-Loreal-graph-creation\venv\Lib\site-packages\neo4j\_optional_deps\__init__.py:29
#      26 pd: t.Any = None
#      28 with suppress(ImportError):
# ---> 29     import pandas as pd  # type: ignore[no-redef]
#      32 __all__ = [
#      33     "np",
#      34     "pd",
#      35 ]
#
# File c:\Users\Jiahe\OneDrive\Documents\Capstone\dsi-capstone-spring-2025-Loreal-graph-creation\venv\Lib\site-packages\pandas\__init__.py:62
#      59 # let init-time option registration happen
#      60 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 62 from pandas.core.api import (
#      63     # dtype
#      64     ArrowDtype,
#      65     Int8Dtype,
#      66     Int16Dtype,
#      67     Int32Dtype,
#      68     Int64Dtype,
#      69     UInt8Dtype,
#      70     UInt16Dtype,
#      71     UInt32Dtype,
#      72     UInt64Dtype,
#      73     Float32Dtype,
#      74     Float64Dtype,
#      75     CategoricalDtype,
#      76     PeriodDtype,
#      77     IntervalDtype,
#      78     DatetimeTZDtype,
#      79     StringDtype,
#      80     BooleanDtype,
#      81     # missing
#      82     NA,
#      83     isna,
#      84     isnull,
#      85     notna,
#      86     notnull,
#      87     # indexes
#      88     Index,
#      89     CategoricalIndex,
#      90     RangeIndex,
#      91     MultiIndex,
#      92     IntervalIndex,
#      93     TimedeltaIndex,
#      94     DatetimeIndex,
#      95     PeriodIndex,
#      96     IndexSlice,
#      97     # tseries
#      98     NaT,
#      99     Period,
#     100     period_range,
#     101     Timedelta,
#     102     timedelta_range,
#     103     Timestamp,
#     104     date_range,
#     105     bdate_range,
#     106     Interval,
#     107     interval_range,
#     108     DateOffset,
#     109     # conversion
#     110     to_numeric,
#     111     to_datetime,
#     112     to_timedelta,
#     113     # misc
#     114     Flags,
#     115     Grouper,
#     116     factorize,
#     117     unique,
#     118     value_counts,
#     119     NamedAgg,
#     120     array,
#     121     Categorical,
#     122     set_eng_float_format,
#     123     Series,
#     124     DataFrame,
#     125 )
#     127 from pandas.core.dtypes.dtypes import SparseDtype
#     129 from pandas.tseries.api import infer_freq
#
# File c:\Users\Jiahe\OneDrive\Documents\Capstone\dsi-capstone-spring-2025-Loreal-graph-creation\venv\Lib\site-packages\pandas\core\api.py:1
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
#       9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#    (...)     14     PeriodDtype,
#      15 )
#
# File c:\Users\Jiahe\OneDrive\Documents\Capstone\dsi-capstone-spring-2025-Loreal-graph-creation\venv\Lib\site-packages\pandas\_libs\__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)     26     iNaT,
#      27 )
#
# File interval.pyx:1, in init pandas._libs.interval()
#
# File hashtable.pyx:1, in init pandas._libs.hashtable()
#
# File missing.pyx:1, in init pandas._libs.missing()
#
# File c:\Users\Jiahe\OneDrive\Documents\Capstone\dsi-capstone-spring-2025-Loreal-graph-creation\venv\Lib\site-packages\pandas\_libs\tslibs\__init__.py:40
#       1 __all__ = [
#       2     "dtypes",
#       3     "localize_pydatetime",
#    (...)     36     "is_supported_dtype",
#      37 ]
#      39 from pandas._libs.tslibs import dtypes  # pylint: disable=import-self
# ---> 40 from pandas._libs.tslibs.conversion import localize_pydatetime
#      41 from pandas._libs.tslibs.dtypes import (
#      42     Resolution,
#      43     periods_per_day,
#      44     periods_per_second,
#      45 )
#      46 from pandas._libs.tslibs.nattype import (
#      47     NaT,
#      48     NaTType,
#      49     iNaT,
#      50     nat_strings,
#      51 )
#
# File conversion.pyx:1, in init pandas._libs.tslibs.conversion()
#
# File offsets.pyx:1, in init pandas._libs.tslibs.offsets()
#
# File <frozen importlib._bootstrap>:405, in parent(self)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Load environment variables
load_dotenv('.env')
# Out:
# True

# %%
# Neo4j configuration & constraints
neo4j_url = os.getenv("NEO4J_CONNECTION_URL")
neo4j_user = os.getenv("NEO4J_USER")
neo4j_password = os.getenv("NEO4J_PASSWORD")
gds = GraphDatabase.driver(neo4j_url, auth=(neo4j_user, neo4j_password))

# %%
raw_csv_path = "amazon_products/cosmetics_25_products.csv"

# %%
openai_deployment = "gpt-4"
client = openai.OpenAI()

def extract_json_block(text):
    match = re.search(r"\{[\s\S]*\}", text)
    if match:
        return match.group(0)
    return None

def process_gpt(prompt, system_msg):
    completion = client.chat.completions.create(
        model=openai_deployment,
        temperature=0,
        max_tokens=2000,
        messages=[
            {"role": "system", "content": system_msg},
            {"role": "user", "content": prompt}
        ],
    )
    
    sleep(0.5)
    
    return completion.choices[0].message.content

def extract_entities_relationships_from_csv(csv_file, prompt_template):
    system_msg = "You are a beauty and personal care expert who understands structured product relationships."
    results = []
    MAX_INGREDIENTS = 10
    MAX_DESCRIPTION_LENGTH = 500

    # Use pandas to safely load the CSV
    df = pd.read_csv(csv_file, quotechar='"', escapechar='\\', engine='python', encoding='utf-8-sig')

    for _, row in df.iterrows():
        try:
            ingredients = row.get("Ingredients", "")
            if ingredients.count(",") > MAX_INGREDIENTS:
                ingredients = ",".join(ingredients.split(",")[:MAX_INGREDIENTS]) + "..."
            prompt = Template(prompt_template).substitute(
                label=row.get("Label", ""),
                brand=row.get("Brand", ""),
                name=row.get("Name", ""),
                price=row.get("Price", ""),
                rank=row.get("Rank", ""),
                ingredients=ingredients,
                for_skin_type=row.get("For_Skin_Type", ""),
                size=row.get("Size", ""),
                description=row.get("Description", ""),
            )

            result = process_gpt(prompt, system_msg)
            json_str = extract_json_block(result)
            print("--- Extracted JSON Block ---")
            print(json_str)
            if json_str:
                results.append(json.loads(json_str))

            print(f"Successfully executed row {row.get('Name', '')}")

        except Exception as e:
            print(f"Failed on row {row.get('Name', '')}: {e}")
            continue

    return results

# %%
def normalize_id(name):
    """Create a consistent alphanumeric ID for any entity."""
    return re.sub(r'[^a-z0-9]', '_', name.lower()).strip('_')

def generate_cypher(json_obj):
    e_statements = []
    r_statements = []
    e_label_map = {}
    skipped_relationships = []

    for i, obj in enumerate(json_obj):
        print(f"Generating cypher for file {i + 1} of {len(json_obj)}")

        for entity in obj.get("entities", []):
            label = entity.get("label")
            raw_id = entity.get("id")
            entity_id = normalize_id(raw_id)

            # Normalize and set properties (excluding label/id)
            properties = {k: v for k, v in entity.items() if k not in ["label", "id"]}
            prop_str = ", ".join([f'n.{k} = {json.dumps(v)}' for k, v in properties.items()])

            cypher = f'MERGE (n:{label} {{id: "{entity_id}"}})'
            if properties:
                cypher += f' ON CREATE SET {prop_str}'

            e_statements.append(cypher)
            e_label_map[entity_id] = label  # Map normalized ID to label

        for rs in obj.get("relationships", []):
            try:
                parts = rs.split("|")
                if len(parts) != 3:
                    raise ValueError(f"Invalid relationship format: {rs}")
                src_raw, rel_type, tgt_raw = parts
                src_id = normalize_id(src_raw)
                tgt_id = normalize_id(tgt_raw)

                if src_id in e_label_map and tgt_id in e_label_map:
                    src_label = e_label_map[src_id]
                    tgt_label = e_label_map[tgt_id]
                    cypher = (
                        f'MATCH (a:{src_label} {{id: "{src_id}"}}) '
                        f'MATCH (b:{tgt_label} {{id: "{tgt_id}"}}) '
                        f'MERGE (a)-[:{rel_type}]->(b)'
                    )
                    r_statements.append(cypher)
                else:
                    skipped_relationships.append(rs)
            except Exception as e:
                print(f"Error processing relationship {rs}: {e}")
                skipped_relationships.append(rs)

    if skipped_relationships:
        print("\n Warning: Skipped relationships due to missing entities:")
        for rs in skipped_relationships:
            print(f"- {rs}")
        with open("skipped_relationships.txt", "w") as f:
            f.write("\n".join(skipped_relationships))

    with open("cyphers.txt", "w") as outfile:
        outfile.write("\n".join(e_statements + r_statements))

    return e_statements + r_statements

# %%
relationship_prompt = """
Given the following structured data for a beauty product, extract all relevant entities and relationships in JSON format with keys "entities" and "relationships".

Ensure:
- All entity "label" fields use valid Cypher label names: no spaces, use PascalCase or snake_case (e.g., SkinType instead of "Skin Type").
- All "id" fields are unique and consistent across entities and relationships.
- Use relationship types in ALL_CAPS_WITH_UNDERSCORES, and entity labels in PascalCase or snake_case.

Data:
{
  "label": "$label",
  "brand": "$brand",
  "name": "$name",
  "price": "$price",
  "rank": "$rank",
  "ingredients": "$ingredients",
  "for_skin_type": "$for_skin_type",
  "size": "$size",
  "description": "$description"
}

Format:
{
  "entities": [
    {"id": "unique_product_id", "label": "Product", "name": "$name", "brand": "$brand", "price": "$price", "rank": "$rank", "size": "$size"},
    {"id": "ingredient_id", "label": "Ingredient", "name": "Ingredient Name"},
    {"id": "skin_type_id", "label": "SkinType", "name": "Dry"},
    ...
  ],
  "relationships": [
    {"source": "unique_product_id", "relationship": "CONTAINS", "target": "ingredient_id"},
    {"source": "unique_product_id", "relationship": "SUITABLE_FOR", "target": "skin_type_id"},
    ...
  ]
}
"""

# %%
relationship_prompt = """
From the product description below, extract Entities & Relationships in an open format. You are free to:

1. Create any entity types you identify, with relevant attributes. Each entity must include:
    - label: The type of entity (e.g., 'Product', 'Ingredient', 'Benefit', etc.)
    - id: A globally unique, clean identifier derived from the entity's main name or value.
    - Any useful attributes (e.g., name, brand, function, effect, category, texture, step, price, rating, size, etc.)

2. Create relationships between:
    - Entities in this description
    - Referenced entities (other products, brands, steps, concerns, etc.)
    - For relationships between product entities, use relationship types like:
        - SAME_BRAND_AS, SIMILAR_PRICE_TIER_AS, SHARES_INGREDIENT_WITH, ADDRESSES_SAME_CONCERN, USED_IN_SAME_STEP, COMPLEMENTS, ALTERNATIVE_TO, PART_OF_COLLECTION, etc.

3. Output format MUST be valid JSON:
{
  "entities": [
    {"label": "EntityType", "id": "unique_id", ...attributes...},
    ...
  ],
  "relationships": [
    "source_id|RELATIONSHIP_TYPE|target_id",
    ...
  ]
}

Guidelines:
- All entity `id` values must be lowercase, alphanumeric strings derived from the entity's name/value (spaces and punctuation replaced with underscores).
- All entity "label" fields use valid Cypher label names: no spaces, use PascalCase or snake_case (e.g., SkinType instead of "Skin Type").
- Use relationship types in ALL_CAPS_WITH_UNDERSCORES.
- Do NOT include hardcoded examples or unrelated product names.
- Avoid duplication: if multiple entities refer to the same concept (e.g. “Water”), use the same `id`.
- Each relationship must reference entities defined in the `entities` list.
- Merge entity data by `id` to avoid partial duplicates.

Now process this structured input:

{
  "label": "$label",
  "brand": "$brand",
  "name": "$name",
  "price": "$price",
  "rank": "$rank",
  "ingredients": "$ingredients",
  "for_skin_type": "$for_skin_type",
  "size": "$size",
  "description": "$description"
}
"""

# %%
def run_csv_ingestion(csv_path):
    json_obj = extract_entities_relationships_from_csv(csv_path, relationship_prompt)
    cypher_statements = generate_cypher(json_obj)

    for stmt in cypher_statements:
        print(f"Running: {stmt}")
        # Execute the Cypher statement in your Neo4j database
        # Example: gds.execute_query(stmt)

run_csv_ingestion("amazon_products/cosmetics_25_products.csv")
# Out:
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "facial_treatment_essence",
#       "brand": "SK-II",
#       "name": "Facial Treatment Essence",
#       "price": "179",
#       "rank": "4.1",
#       "size": "5.0 oz (150ml)",
#       "category": "Moisturizer"
#     },
#     {
#       "label": "Ingredient",
#       "id": "galactomyces_ferment_filtrate",
#       "name": "Galactomyces Ferment Filtrate (Pitera)"
#     },
#     {
#       "label": "Ingredient",
#       "id": "butylene_glycol",
#       "name": "Butylene Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "pentylene_glycol",
#       "name": "Pentylene Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "water",
#       "name": "Water"
#     },
#     {
#       "label": "Ingredient",
#       "id": "sodium_benzoate",
#       "name": "Sodium Benzoate"
#     },
#     {
#       "label": "Ingredient",
#       "id": "methylparaben",
#       "name": "Methylparaben"
#     },
#     {
#       "label": "Ingredient",
#       "id": "sorbic_acid",
#       "name": "Sorbic Acid"
#     },
#     {
#       "label": "Benefit",
#       "id": "promotes_skin_cell_renewal",
#       "name": "Promotes skin cell renewal"
#     },
#     {
#       "label": "Benefit",
#       "id": "reduces_wrinkles",
#       "name": "Reduces wrinkles"
#     },
#     {
#       "label": "Benefit",
#       "id": "refines_texture",
#       "name": "Refines texture"
#     },
#     {
#       "label": "Benefit",
#       "id": "improves_radiance",
#       "name": "Improves radiance"
#     }
#   ],
#   "relationships": [
#     "facial_treatment_essence|CONTAINS_INGREDIENT|galactomyces_ferment_filtrate",
#     "facial_treatment_essence|CONTAINS_INGREDIENT|butylene_glycol",
#     "facial_treatment_essence|CONTAINS_INGREDIENT|pentylene_glycol",
#     "facial_treatment_essence|CONTAINS_INGREDIENT|water",
#     "facial_treatment_essence|CONTAINS_INGREDIENT|sodium_benzoate",
#     "facial_treatment_essence|CONTAINS_INGREDIENT|methylparaben",
#     "facial_treatment_essence|CONTAINS_INGREDIENT|sorbic_acid",
#     "facial_treatment_essence|PROVIDES_BENEFIT|promotes_skin_cell_renewal",
#     "facial_treatment_essence|PROVIDES_BENEFIT|reduces_wrinkles",
#     "facial_treatment_essence|PROVIDES_BENEFIT|refines_texture",
#     "facial_treatment_essence|PROVIDES_BENEFIT|improves_radiance"
#   ]
# }
# Successfully executed row Facial Treatment Essence
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "the_moisturizing_soft_cream",
#       "brand": "LA MER",
#       "name": "The Moisturizing Soft Cream",
#       "price": "175",
#       "rank": "3.8",
#       "size": "1.0 oz (30ml)",
#       "category": "Moisturizer",
#       "description": "A silky-soft cream powered by miracle broth that delivers healing moisture, visibly diminishes fine lines, and helps skin look firmer, healthier, and revitalized while strengthening the skin barrier."
#     },
#     {
#       "label": "Ingredient",
#       "id": "algae_seaweed_extract",
#       "name": "Algae (Seaweed) Extract"
#     },
#     {
#       "label": "Ingredient",
#       "id": "cyclopentasiloxane",
#       "name": "Cyclopentasiloxane"
#     },
#     {
#       "label": "Ingredient",
#       "id": "petrolatum",
#       "name": "Petrolatum"
#     },
#     {
#       "label": "Ingredient",
#       "id": "glyceryl_distearate",
#       "name": "Glyceryl Distearate"
#     },
#     {
#       "label": "Ingredient",
#       "id": "phenyl_trimethicone",
#       "name": "Phenyl Trimethicone"
#     },
#     {
#       "label": "Ingredient",
#       "id": "butylene_glycol",
#       "name": "Butylene Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "hydrogenated_vegetable_oil",
#       "name": "Hydrogenated Vegetable Oil"
#     },
#     {
#       "label": "Ingredient",
#       "id": "cholesterol",
#       "name": "Cholesterol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "butyrospermum_parkii_shea_butter",
#       "name": "Butyrospermum Parkii (Shea Butter)"
#     },
#     {
#       "label": "Ingredient",
#       "id": "steareth_10",
#       "name": "Steareth-10"
#     },
#     {
#       "label": "Benefit",
#       "id": "healing_moisture",
#       "name": "Healing Moisture"
#     },
#     {
#       "label": "Benefit",
#       "id": "diminishes_fine_lines",
#       "name": "Diminishes Fine Lines"
#     },
#     {
#       "label": "Benefit",
#       "id": "firmer_skin",
#       "name": "Firmer Skin"
#     },
#     {
#       "label": "Benefit",
#       "id": "healthier_skin",
#       "name": "Healthier Skin"
#     },
#     {
#       "label": "Benefit",
#       "id": "revitalized_skin",
#       "name": "Revitalized Skin"
#     },
#     {
#       "label": "Benefit",
#       "id": "strengthening_skin_barrier",
#       "name": "Strengthening Skin Barrier"
#     }
#   ],
#   "relationships": [
#     "the_moisturizing_soft_cream|CONTAINS_INGREDIENT|algae_seaweed_extract",
#     "the_moisturizing_soft_cream|CONTAINS_INGREDIENT|cyclopentasiloxane",
#     "the_moisturizing_soft_cream|CONTAINS_INGREDIENT|petrolatum",
#     "the_moisturizing_soft_cream|CONTAINS_INGREDIENT|glyceryl_distearate",
#     "the_moisturizing_soft_cream|CONTAINS_INGREDIENT|phenyl_trimethicone",
#     "the_moisturizing_soft_cream|CONTAINS_INGREDIENT|butylene_glycol",
#     "the_moisturizing_soft_cream|CONTAINS_INGREDIENT|hydrogenated_vegetable_oil",
#     "the_moisturizing_soft_cream|CONTAINS_INGREDIENT|cholesterol",
#     "the_moisturizing_soft_cream|CONTAINS_INGREDIENT|butyrospermum_parkii_shea_butter",
#     "the_moisturizing_soft_cream|CONTAINS_INGREDIENT|steareth_10",
#     "the_moisturizing_soft_cream|PROVIDES_BENEFIT|healing_moisture",
#     "the_moisturizing_soft_cream|PROVIDES_BENEFIT|diminishes_fine_lines",
#     "the_moisturizing_soft_cream|PROVIDES_BENEFIT|firmer_skin",
#     "the_moisturizing_soft_cream|PROVIDES_BENEFIT|healthier_skin",
#     "the_moisturizing_soft_cream|PROVIDES_BENEFIT|revitalized_skin",
#     "the_moisturizing_soft_cream|PROVIDES_BENEFIT|strengthening_skin_barrier"
#   ]
# }
# Successfully executed row The Moisturizing Soft Cream
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "genoptics_aura_essence_serum",
#       "brand": "SK-II",
#       "name": "GenOptics Aura Essence Serum",
#       "price": "240",
#       "rank": "4.1",
#       "size": "1.7 oz (50ml)",
#       "category": "Moisturizer"
#     },
#     {
#       "label": "Ingredient",
#       "id": "water",
#       "name": "Water"
#     },
#     {
#       "label": "Ingredient",
#       "id": "galactomyces_ferment_filtrate_pitera",
#       "name": "Galactomyces Ferment Filtrate (Pitera)"
#     },
#     {
#       "label": "Ingredient",
#       "id": "niacinamide",
#       "name": "Niacinamide"
#     },
#     {
#       "label": "Ingredient",
#       "id": "butylene_glycol",
#       "name": "Butylene Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "triethylhexanoin",
#       "name": "Triethylhexanoin"
#     },
#     {
#       "label": "Ingredient",
#       "id": "pentylene_glycol",
#       "name": "Pentylene Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "glycerin",
#       "name": "Glycerin"
#     },
#     {
#       "label": "Ingredient",
#       "id": "nylon_12",
#       "name": "Nylon-12"
#     },
#     {
#       "label": "Ingredient",
#       "id": "phytosteryl_octyldodecyl_lauroyl_glutamate",
#       "name": "Phytosteryl/Octyldodecyl Lauroyl Glutamate"
#     },
#     {
#       "label": "Ingredient",
#       "id": "polymethylsilsesquioxane",
#       "name": "Polymethylsilsesquioxane"
#     },
#     {
#       "label": "Benefit",
#       "id": "brightening",
#       "name": "Brightening"
#     },
#     {
#       "label": "Benefit",
#       "id": "targets_dark_spots_and_dullness",
#       "name": "Targets dark spots and dullness"
#     },
#     {
#       "label": "Benefit",
#       "id": "reduces_appearance_of_melanin",
#       "name": "Reduces appearance of melanin"
#     },
#     {
#       "label": "Benefit",
#       "id": "promotes_radiant_even_toned_complexion",
#       "name": "Promotes radiant, even-toned complexion"
#     }
#   ],
#   "relationships": [
#     "genoptics_aura_essence_serum|CONTAINS_INGREDIENT|water",
#     "genoptics_aura_essence_serum|CONTAINS_INGREDIENT|galactomyces_ferment_filtrate_pitera",
#     "genoptics_aura_essence_serum|CONTAINS_INGREDIENT|niacinamide",
#     "genoptics_aura_essence_serum|CONTAINS_INGREDIENT|butylene_glycol",
#     "genoptics_aura_essence_serum|CONTAINS_INGREDIENT|triethylhexanoin",
#     "genoptics_aura_essence_serum|CONTAINS_INGREDIENT|pentylene_glycol",
#     "genoptics_aura_essence_serum|CONTAINS_INGREDIENT|glycerin",
#     "genoptics_aura_essence_serum|CONTAINS_INGREDIENT|nylon_12",
#     "genoptics_aura_essence_serum|CONTAINS_INGREDIENT|phytosteryl_octyldodecyl_lauroyl_glutamate",
#     "genoptics_aura_essence_serum|CONTAINS_INGREDIENT|polymethylsilsesquioxane",
#     "genoptics_aura_essence_serum|HAS_BENEFIT|brightening",
#     "genoptics_aura_essence_serum|HAS_BENEFIT|targets_dark_spots_and_dullness",
#     "genoptics_aura_essence_serum|HAS_BENEFIT|reduces_appearance_of_melanin",
#     "genoptics_aura_essence_serum|HAS_BENEFIT|promotes_radiant_even_toned_complexion"
#   ]
# }
# Successfully executed row GenOptics Aura Essence Serum
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "facial_treatment_essence_mini",
#       "brand": "SK-II",
#       "name": "Facial Treatment Essence Mini",
#       "price": "99",
#       "rank": "4.1",
#       "size": "2.5 oz (75ml)",
#       "category": "Moisturizer",
#       "description": "A travel-sized version of SK-II's iconic essence that delivers the same skin-renewing benefits in a more portable and affordable format."
#     },
#     {
#       "label": "Ingredient",
#       "id": "galactomyces_ferment_filtrate",
#       "name": "Galactomyces Ferment Filtrate (Pitera)"
#     },
#     {
#       "label": "Ingredient",
#       "id": "butylene_glycol",
#       "name": "Butylene Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "pentylene_glycol",
#       "name": "Pentylene Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "water",
#       "name": "Water"
#     },
#     {
#       "label": "Ingredient",
#       "id": "sodium_benzoate",
#       "name": "Sodium Benzoate"
#     },
#     {
#       "label": "Ingredient",
#       "id": "methylparaben",
#       "name": "Methylparaben"
#     },
#     {
#       "label": "Ingredient",
#       "id": "sorbic_acid",
#       "name": "Sorbic Acid"
#     },
#     {
#       "label": "Brand",
#       "id": "sk-ii",
#       "name": "SK-II"
#     }
#   ],
#   "relationships": [
#     "facial_treatment_essence_mini|HAS_INGREDIENT|galactomyces_ferment_filtrate",
#     "facial_treatment_essence_mini|HAS_INGREDIENT|butylene_glycol",
#     "facial_treatment_essence_mini|HAS_INGREDIENT|pentylene_glycol",
#     "facial_treatment_essence_mini|HAS_INGREDIENT|water",
#     "facial_treatment_essence_mini|HAS_INGREDIENT|sodium_benzoate",
#     "facial_treatment_essence_mini|HAS_INGREDIENT|methylparaben",
#     "facial_treatment_essence_mini|HAS_INGREDIENT|sorbic_acid",
#     "facial_treatment_essence_mini|BRAND|sk-ii"
#   ]
# }
# Successfully executed row Facial Treatment Essence Mini
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "the_moisturizing_cool_gel_cream",
#       "brand": "LA MER",
#       "name": "The Moisturizing Cool Gel Cream",
#       "price": "175",
#       "rank": "3.3",
#       "size": "1.0 oz (30ml)",
#       "category": "Moisturizer",
#       "description": "A lightweight gel cream that delivers the benefits of La Mer's miracle broth in a refreshing formula suitable for normal to oily skin types, reducing shine while providing hydration."
#     },
#     {
#       "label": "Brand",
#       "id": "la_mer",
#       "name": "LA MER"
#     },
#     {
#       "label": "Ingredient",
#       "id": "miracle_broth",
#       "name": "Miracle Broth"
#     },
#     {
#       "label": "SkinType",
#       "id": "normal_to_oily",
#       "name": "Normal to Oily"
#     },
#     {
#       "label": "Benefit",
#       "id": "reducing_shine",
#       "name": "Reducing Shine"
#     },
#     {
#       "label": "Benefit",
#       "id": "providing_hydration",
#       "name": "Providing Hydration"
#     }
#   ],
#   "relationships": [
#     "the_moisturizing_cool_gel_cream|BRAND|la_mer",
#     "the_moisturizing_cool_gel_cream|CONTAINS_INGREDIENT|miracle_broth",
#     "the_moisturizing_cool_gel_cream|FOR_SKIN_TYPE|normal_to_oily",
#     "the_moisturizing_cool_gel_cream|PROVIDES_BENEFIT|reducing_shine",
#     "the_moisturizing_cool_gel_cream|PROVIDES_BENEFIT|providing_hydration"
#   ]
# }
# Successfully executed row The Moisturizing Cool Gel Cream
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "ultra_facial_oil_free_gel_cream",
#       "brand": "KIEHL'S SINCE 1851",
#       "name": "Ultra Facial Oil-Free Gel-Cream",
#       "price": "29",
#       "rank": "4.1",
#       "size": "1.7 oz (50ml)",
#       "category": "Moisturizer"
#     },
#     {
#       "label": "Ingredient",
#       "id": "water",
#       "name": "Water"
#     },
#     {
#       "label": "Ingredient",
#       "id": "glycerin",
#       "name": "Glycerin"
#     },
#     {
#       "label": "Ingredient",
#       "id": "alcohol_denat",
#       "name": "Alcohol Denat."
#     },
#     {
#       "label": "Ingredient",
#       "id": "dimethicone",
#       "name": "Dimethicone"
#     },
#     {
#       "label": "Ingredient",
#       "id": "isononyl_isononanoate",
#       "name": "Isononyl Isononanoate"
#     },
#     {
#       "label": "Ingredient",
#       "id": "carbomer",
#       "name": "Carbomer"
#     },
#     {
#       "label": "Ingredient",
#       "id": "imperata_cylindrica_root_extract",
#       "name": "Imperata Cylindrica Root Extract"
#     },
#     {
#       "label": "Ingredient",
#       "id": "dimethiconol",
#       "name": "Dimethiconol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "caprylyl_glycol",
#       "name": "Caprylyl Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "chlorphenesin",
#       "name": "Chlorphenesin"
#     },
#     {
#       "label": "Benefit",
#       "id": "shine_reducing",
#       "name": "Shine-Reducing"
#     },
#     {
#       "label": "Benefit",
#       "id": "oil_free",
#       "name": "Oil-Free"
#     },
#     {
#       "label": "Benefit",
#       "id": "24_hour_hydration",
#       "name": "24-Hour Hydration"
#     },
#     {
#       "label": "Benefit",
#       "id": "non_greasy",
#       "name": "Non-Greasy"
#     },
#     {
#       "label": "SkinType",
#       "id": "oily_skin",
#       "name": "Oily Skin"
#     },
#     {
#       "label": "SkinType",
#       "id": "normal_skin",
#       "name": "Normal Skin"
#     }
#   ],
#   "relationships": [
#     "ultra_facial_oil_free_gel_cream|CONTAINS_INGREDIENT|water",
#     "ultra_facial_oil_free_gel_cream|CONTAINS_INGREDIENT|glycerin",
#     "ultra_facial_oil_free_gel_cream|CONTAINS_INGREDIENT|alcohol_denat",
#     "ultra_facial_oil_free_gel_cream|CONTAINS_INGREDIENT|dimethicone",
#     "ultra_facial_oil_free_gel_cream|CONTAINS_INGREDIENT|isononyl_isononanoate",
#     "ultra_facial_oil_free_gel_cream|CONTAINS_INGREDIENT|carbomer",
#     "ultra_facial_oil_free_gel_cream|CONTAINS_INGREDIENT|imperata_cylindrica_root_extract",
#     "ultra_facial_oil_free_gel_cream|CONTAINS_INGREDIENT|dimethiconol",
#     "ultra_facial_oil_free_gel_cream|CONTAINS_INGREDIENT|caprylyl_glycol",
#     "ultra_facial_oil_free_gel_cream|CONTAINS_INGREDIENT|chlorphenesin",
#     "ultra_facial_oil_free_gel_cream|HAS_BENEFIT|shine_reducing",
#     "ultra_facial_oil_free_gel_cream|HAS_BENEFIT|oil_free",
#     "ultra_facial_oil_free_gel_cream|HAS_BENEFIT|24_hour_hydration",
#     "ultra_facial_oil_free_gel_cream|HAS_BENEFIT|non_greasy",
#     "ultra_facial_oil_free_gel_cream|FOR_SKIN_TYPE|oily_skin",
#     "ultra_facial_oil_free_gel_cream|FOR_SKIN_TYPE|normal_skin"
#   ]
# }
# Successfully executed row Ultra Facial Oil-Free Gel-Cream
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "the_moisturizing_soft_lotion",
#       "brand": "LA MER",
#       "name": "The Moisturizing Soft Lotion",
#       "price": "270",
#       "rank": "3.6",
#       "size": "1.7 oz (50ml)",
#       "category": "Moisturizer",
#       "description": "A lightweight, fast-absorbing lotion featuring miracle broth that delivers La Mer's transformative benefits in a more fluid texture suitable for normal to combination skin."
#     },
#     {
#       "label": "Brand",
#       "id": "la_mer",
#       "name": "LA MER"
#     },
#     {
#       "label": "Ingredient",
#       "id": "algae_seaweed_extract",
#       "name": "Algae (Seaweed) Extract"
#     },
#     {
#       "label": "Ingredient",
#       "id": "petrolatum",
#       "name": "Petrolatum"
#     },
#     {
#       "label": "Ingredient",
#       "id": "isocetyl_stearoyl_stearate",
#       "name": "Isocetyl Stearoyl Stearate"
#     },
#     {
#       "label": "Ingredient",
#       "id": "butyrospermum_parkii_shea_butter",
#       "name": "Butyrospermum Parkii (Shea Butter)"
#     },
#     {
#       "label": "Ingredient",
#       "id": "butylene_glycol",
#       "name": "Butylene Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "cyclopentasiloxane",
#       "name": "Cyclopentasiloxane"
#     },
#     {
#       "label": "Ingredient",
#       "id": "dimethicone",
#       "name": "Dimethicone"
#     },
#     {
#       "label": "Ingredient",
#       "id": "glyceryl_stearate",
#       "name": "Glyceryl Stearate"
#     },
#     {
#       "label": "Ingredient",
#       "id": "cetyl_esters",
#       "name": "Cetyl Esters"
#     },
#     {
#       "label": "Ingredient",
#       "id": "phenyl_trimethicone",
#       "name": "Phenyl Trimethicone"
#     },
#     {
#       "label": "Benefit",
#       "id": "fast_absorbing",
#       "name": "Fast Absorbing"
#     },
#     {
#       "label": "Benefit",
#       "id": "lightweight",
#       "name": "Lightweight"
#     },
#     {
#       "label": "Benefit",
#       "id": "suitable_for_normal_to_combination_skin",
#       "name": "Suitable for Normal to Combination Skin"
#     }
#   ],
#   "relationships": [
#     "the_moisturizing_soft_lotion|BRAND|la_mer",
#     "the_moisturizing_soft_lotion|CONTAINS_INGREDIENT|algae_seaweed_extract",
#     "the_moisturizing_soft_lotion|CONTAINS_INGREDIENT|petrolatum",
#     "the_moisturizing_soft_lotion|CONTAINS_INGREDIENT|isocetyl_stearoyl_stearate",
#     "the_moisturizing_soft_lotion|CONTAINS_INGREDIENT|butyrospermum_parkii_shea_butter",
#     "the_moisturizing_soft_lotion|CONTAINS_INGREDIENT|butylene_glycol",
#     "the_moisturizing_soft_lotion|CONTAINS_INGREDIENT|cyclopentasiloxane",
#     "the_moisturizing_soft_lotion|CONTAINS_INGREDIENT|dimethicone",
#     "the_moisturizing_soft_lotion|CONTAINS_INGREDIENT|glyceryl_stearate",
#     "the_moisturizing_soft_lotion|CONTAINS_INGREDIENT|cetyl_esters",
#     "the_moisturizing_soft_lotion|CONTAINS_INGREDIENT|phenyl_trimethicone",
#     "the_moisturizing_soft_lotion|HAS_BENEFIT|fast_absorbing",
#     "the_moisturizing_soft_lotion|HAS_BENEFIT|lightweight",
#     "the_moisturizing_soft_lotion|HAS_BENEFIT|suitable_for_normal_to_combination_skin"
#   ]
# }
# Successfully executed row The Moisturizing Soft Lotion
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "resilience_lift_night_lifting_firming_face_and_neck_creme",
#       "brand": "ESTÉE LAUDER",
#       "name": "Resilience Lift Night Lifting/Firming Face and Neck Creme",
#       "price": "92",
#       "rank": "4.2",
#       "size": "1.7 oz (50ml)",
#       "category": "Moisturizer"
#     },
#     {
#       "label": "Brand",
#       "id": "estee_lauder",
#       "name": "ESTÉE LAUDER"
#     },
#     {
#       "label": "Ingredient",
#       "id": "photo_activated_lifters",
#       "name": "Photo-Activated Lifters"
#     },
#     {
#       "label": "Technology",
#       "id": "advanced_technology",
#       "name": "Advanced Technology"
#     },
#     {
#       "label": "Benefit",
#       "id": "anti_aging",
#       "name": "Anti-Aging"
#     },
#     {
#       "label": "Benefit",
#       "id": "lift_firm_repair_skin",
#       "name": "Lift, Firm, and Repair Skin"
#     },
#     {
#       "label": "Benefit",
#       "id": "counter_effects_of_gravity_and_loss_of_elasticity",
#       "name": "Counter the Effects of Gravity and Loss of Elasticity"
#     },
#     {
#       "label": "Usage",
#       "id": "night_use",
#       "name": "Night Use"
#     }
#   ],
#   "relationships": [
#     "resilience_lift_night_lifting_firming_face_and_neck_creme|BRAND|estee_lauder",
#     "resilience_lift_night_lifting_firming_face_and_neck_creme|CONTAINS_INGREDIENT|photo_activated_lifters",
#     "resilience_lift_night_lifting_firming_face_and_neck_creme|USES_TECHNOLOGY|advanced_technology",
#     "resilience_lift_night_lifting_firming_face_and_neck_creme|PROVIDES_BENEFIT|anti_aging",
#     "resilience_lift_night_lifting_firming_face_and_neck_creme|PROVIDES_BENEFIT|lift_firm_repair_skin",
#     "resilience_lift_night_lifting_firming_face_and_neck_creme|PROVIDES_BENEFIT|counter_effects_of_gravity_and_loss_of_elasticity",
#     "resilience_lift_night_lifting_firming_face_and_neck_creme|FOR_USAGE|night_use"
#   ]
# }
# Successfully executed row Resilience Lift Night Lifting/Firming Face and Neck Creme
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "ultra_facial_moisturizer",
#       "brand": "KIEHL'S SINCE 1851",
#       "name": "Ultra Facial Moisturizer",
#       "price": "29",
#       "rank": "3.9",
#       "size": "2.5 oz (75ml)",
#       "category": "Moisturizer",
#       "description": "A lightweight daily moisturizer with a blend of botanical extracts and emollients to provide essential hydration without heaviness, suitable for all skin types."
#     },
#     {
#       "label": "Brand",
#       "id": "kiehl's_since_1851",
#       "name": "KIEHL'S SINCE 1851"
#     },
#     {
#       "label": "Ingredient",
#       "id": "water",
#       "name": "Water"
#     },
#     {
#       "label": "Ingredient",
#       "id": "squalane",
#       "name": "Squalane"
#     },
#     {
#       "label": "Ingredient",
#       "id": "glycerin",
#       "name": "Glycerin"
#     },
#     {
#       "label": "Ingredient",
#       "id": "peg-100_stearate",
#       "name": "Peg-100 Stearate"
#     },
#     {
#       "label": "Ingredient",
#       "id": "glyceryl_stearate",
#       "name": "Glyceryl Stearate"
#     },
#     {
#       "label": "Ingredient",
#       "id": "butylene_glycol",
#       "name": "Butylene Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "triethanolamine",
#       "name": "Triethanolamine"
#     },
#     {
#       "label": "Ingredient",
#       "id": "phenoxyethanol",
#       "name": "Phenoxyethanol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "sorbitan_oleate",
#       "name": "Sorbitan Oleate"
#     },
#     {
#       "label": "Ingredient",
#       "id": "carbomer",
#       "name": "Carbomer"
#     },
#     {
#       "label": "Ingredient",
#       "id": "methylparaben",
#       "name": "Methylparaben"
#     },
#     {
#       "label": "Benefit",
#       "id": "hydration",
#       "name": "Hydration"
#     },
#     {
#       "label": "Texture",
#       "id": "lightweight",
#       "name": "Lightweight"
#     },
#     {
#       "label": "SkinType",
#       "id": "all_skin_types",
#       "name": "All Skin Types"
#     }
#   ],
#   "relationships": [
#     "ultra_facial_moisturizer|BRAND|kiehl's_since_1851",
#     "ultra_facial_moisturizer|CONTAINS_INGREDIENT|water",
#     "ultra_facial_moisturizer|CONTAINS_INGREDIENT|squalane",
#     "ultra_facial_moisturizer|CONTAINS_INGREDIENT|glycerin",
#     "ultra_facial_moisturizer|CONTAINS_INGREDIENT|peg-100_stearate",
#     "ultra_facial_moisturizer|CONTAINS_INGREDIENT|glyceryl_stearate",
#     "ultra_facial_moisturizer|CONTAINS_INGREDIENT|butylene_glycol",
#     "ultra_facial_moisturizer|CONTAINS_INGREDIENT|triethanolamine",
#     "ultra_facial_moisturizer|CONTAINS_INGREDIENT|phenoxyethanol",
#     "ultra_facial_moisturizer|CONTAINS_INGREDIENT|sorbitan_oleate",
#     "ultra_facial_moisturizer|CONTAINS_INGREDIENT|carbomer",
#     "ultra_facial_moisturizer|CONTAINS_INGREDIENT|methylparaben",
#     "ultra_facial_moisturizer|HAS_BENEFIT|hydration",
#     "ultra_facial_moisturizer|HAS_TEXTURE|lightweight",
#     "ultra_facial_moisturizer|FOR_SKIN_TYPE|all_skin_types"
#   ]
# }
# Successfully executed row Ultra Facial Moisturizer
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "advanced_night_repair_intensive_recovery_ampoules",
#       "brand": "ESTÉE LAUDER",
#       "name": "Advanced Night Repair Intensive Recovery Ampoules",
#       "price": "115",
#       "rank": "4.9",
#       "size": "60 capsules",
#       "category": "Moisturizer",
#       "description": "Single-dose, powerful recovery ampoules that help repair skin overnight, providing intensive treatment to boost skin's natural repair processes and strengthen the moisture barrier."
#     },
#     {
#       "label": "Ingredient",
#       "id": "caprylic_capric_triglyceride",
#       "name": "Caprylic/Capric Triglyceride"
#     },
#     {
#       "label": "Ingredient",
#       "id": "squalane",
#       "name": "Squalane"
#     },
#     {
#       "label": "Ingredient",
#       "id": "aleurites_moluccana_seed_oil",
#       "name": "Aleurites Moluccana (Kukui) Seed Oil"
#     },
#     {
#       "label": "Ingredient",
#       "id": "prunus_armeniaca_kernel_oil",
#       "name": "Prunus Armeniaca (Apricot) Kernel Oil"
#     },
#     {
#       "label": "Ingredient",
#       "id": "bisabolol",
#       "name": "Bisabolol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "garcinia_mangostana_peel_extract",
#       "name": "Garcinia Mangostana Peel Extract"
#     },
#     {
#       "label": "Ingredient",
#       "id": "salicornia_herbacea_extract",
#       "name": "Salicornia Herbacea Extract"
#     },
#     {
#       "label": "Ingredient",
#       "id": "magnolia_officinalis_bark_extract",
#       "name": "Magnolia Officinalis Bark Extract"
#     },
#     {
#       "label": "Ingredient",
#       "id": "salvia_hispanica_seed_extract",
#       "name": "Salvia Hispanica Seed Extract"
#     },
#     {
#       "label": "Ingredient",
#       "id": "anthemis_nobilis_flower_extract",
#       "name": "Anthemis Nobilis (Chamomile) Flower Extract"
#     },
#     {
#       "label": "Brand",
#       "id": "estee_lauder",
#       "name": "ESTÉE LAUDER"
#     }
#   ],
#   "relationships": [
#     "advanced_night_repair_intensive_recovery_ampoules|CONTAINS_INGREDIENT|caprylic_capric_triglyceride",
#     "advanced_night_repair_intensive_recovery_ampoules|CONTAINS_INGREDIENT|squalane",
#     "advanced_night_repair_intensive_recovery_ampoules|CONTAINS_INGREDIENT|aleurites_moluccana_seed_oil",
#     "advanced_night_repair_intensive_recovery_ampoules|CONTAINS_INGREDIENT|prunus_armeniaca_kernel_oil",
#     "advanced_night_repair_intensive_recovery_ampoules|CONTAINS_INGREDIENT|bisabolol",
#     "advanced_night_repair_intensive_recovery_ampoules|CONTAINS_INGREDIENT|garcinia_mangostana_peel_extract",
#     "advanced_night_repair_intensive_recovery_ampoules|CONTAINS_INGREDIENT|salicornia_herbacea_extract",
#     "advanced_night_repair_intensive_recovery_ampoules|CONTAINS_INGREDIENT|magnolia_officinalis_bark_extract",
#     "advanced_night_repair_intensive_recovery_ampoules|CONTAINS_INGREDIENT|salvia_hispanica_seed_extract",
#     "advanced_night_repair_intensive_recovery_ampoules|CONTAINS_INGREDIENT|anthemis_nobilis_flower_extract",
#     "advanced_night_repair_intensive_recovery_ampoules|BRAND|estee_lauder"
#   ]
# }
# Successfully executed row Advanced Night Repair Intensive Recovery Ampoules
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "revitalizing_supreme_global_anti_aging_cell_power_creme_spf_15",
#       "name": "Revitalizing Supreme+ Global Anti-Aging Cell Power Creme SPF 15",
#       "brand": "ESTÉE LAUDER",
#       "category": "Moisturizer",
#       "price": "82",
#       "rating": "4.0",
#       "size": "1.7 oz (50ml)",
#       "description": "A multi-action anti-aging moisturizer with SPF protection that helps visibly reduce lines and wrinkles while promoting skin's natural collagen production for a firmer, more youthful appearance."
#     },
#     {
#       "label": "Brand",
#       "id": "estee_lauder",
#       "name": "ESTÉE LAUDER"
#     },
#     {
#       "label": "Benefit",
#       "id": "anti_aging",
#       "name": "Anti-Aging"
#     },
#     {
#       "label": "Benefit",
#       "id": "spf_protection",
#       "name": "SPF Protection"
#     },
#     {
#       "label": "Benefit",
#       "id": "reduce_lines_and_wrinkles",
#       "name": "Reduce Lines and Wrinkles"
#     },
#     {
#       "label": "Benefit",
#       "id": "promote_skin_collagen_production",
#       "name": "Promote Skin's Collagen Production"
#     },
#     {
#       "label": "Benefit",
#       "id": "firmer_skin",
#       "name": "Firmer Skin"
#     },
#     {
#       "label": "Benefit",
#       "id": "youthful_appearance",
#       "name": "Youthful Appearance"
#     }
#   ],
#   "relationships": [
#     "revitalizing_supreme_global_anti_aging_cell_power_creme_spf_15|BRAND|estee_lauder",
#     "revitalizing_supreme_global_anti_aging_cell_power_creme_spf_15|HAS_BENEFIT|anti_aging",
#     "revitalizing_supreme_global_anti_aging_cell_power_creme_spf_15|HAS_BENEFIT|spf_protection",
#     "revitalizing_supreme_global_anti_aging_cell_power_creme_spf_15|HAS_BENEFIT|reduce_lines_and_wrinkles",
#     "revitalizing_supreme_global_anti_aging_cell_power_creme_spf_15|HAS_BENEFIT|promote_skin_collagen_production",
#     "revitalizing_supreme_global_anti_aging_cell_power_creme_spf_15|HAS_BENEFIT|firmer_skin",
#     "revitalizing_supreme_global_anti_aging_cell_power_creme_spf_15|HAS_BENEFIT|youthful_appearance"
#   ]
# }
# Successfully executed row Revitalizing Supreme+ Global Anti-Aging Cell Power Creme SPF 15
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "ultra_facial_cream_spf_30",
#       "brand": "KIEHL'S SINCE 1851",
#       "name": "Ultra Facial Cream SPF 30",
#       "price": "29",
#       "rank": "4.2",
#       "size": "1.7 oz (50ml)",
#       "category": "Moisturizer",
#       "description": "A daily moisturizer with SPF 30 protection that provides lasting hydration without greasiness, helping to shield skin from sun damage while maintaining moisture balance."
#     },
#     {
#       "label": "Brand",
#       "id": "kiehl's_since_1851",
#       "name": "KIEHL'S SINCE 1851"
#     },
#     {
#       "label": "Ingredient",
#       "id": "water",
#       "name": "Water"
#     },
#     {
#       "label": "Ingredient",
#       "id": "glycerin",
#       "name": "Glycerin"
#     },
#     {
#       "label": "Ingredient",
#       "id": "squalane",
#       "name": "Squalane"
#     },
#     {
#       "label": "Ingredient",
#       "id": "dimethicone",
#       "name": "Dimethicone"
#     },
#     {
#       "label": "Ingredient",
#       "id": "peg-100_stearate",
#       "name": "Peg-100 Stearate"
#     },
#     {
#       "label": "Ingredient",
#       "id": "glyceryl_stearate",
#       "name": "Glyceryl Stearate"
#     },
#     {
#       "label": "Ingredient",
#       "id": "silica",
#       "name": "Silica"
#     },
#     {
#       "label": "Ingredient",
#       "id": "octyldodecanol",
#       "name": "Octyldodecanol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "stearic_acid",
#       "name": "Stearic Acid"
#     },
#     {
#       "label": "Ingredient",
#       "id": "phenoxyethanol",
#       "name": "Phenoxyethanol"
#     },
#     {
#       "label": "Benefit",
#       "id": "spf_30_protection",
#       "name": "SPF 30 protection"
#     },
#     {
#       "label": "Benefit",
#       "id": "lasting_hydration",
#       "name": "Lasting hydration"
#     },
#     {
#       "label": "Benefit",
#       "id": "non-greasy",
#       "name": "Non-greasy"
#     },
#     {
#       "label": "Benefit",
#       "id": "shields_skin_from_sun_damage",
#       "name": "Shields skin from sun damage"
#     },
#     {
#       "label": "Benefit",
#       "id": "maintains_moisture_balance",
#       "name": "Maintains moisture balance"
#     }
#   ],
#   "relationships": [
#     "ultra_facial_cream_spf_30|BRAND|kiehl's_since_1851",
#     "ultra_facial_cream_spf_30|CONTAINS_INGREDIENT|water",
#     "ultra_facial_cream_spf_30|CONTAINS_INGREDIENT|glycerin",
#     "ultra_facial_cream_spf_30|CONTAINS_INGREDIENT|squalane",
#     "ultra_facial_cream_spf_30|CONTAINS_INGREDIENT|dimethicone",
#     "ultra_facial_cream_spf_30|CONTAINS_INGREDIENT|peg-100_stearate",
#     "ultra_facial_cream_spf_30|CONTAINS_INGREDIENT|glyceryl_stearate",
#     "ultra_facial_cream_spf_30|CONTAINS_INGREDIENT|silica",
#     "ultra_facial_cream_spf_30|CONTAINS_INGREDIENT|octyldodecanol",
#     "ultra_facial_cream_spf_30|CONTAINS_INGREDIENT|stearic_acid",
#     "ultra_facial_cream_spf_30|CONTAINS_INGREDIENT|phenoxyethanol",
#     "ultra_facial_cream_spf_30|HAS_BENEFIT|spf_30_protection",
#     "ultra_facial_cream_spf_30|HAS_BENEFIT|lasting_hydration",
#     "ultra_facial_cream_spf_30|HAS_BENEFIT|non-greasy",
#     "ultra_facial_cream_spf_30|HAS_BENEFIT|shields_skin_from_sun_damage",
#     "ultra_facial_cream_spf_30|HAS_BENEFIT|maintains_moisture_balance"
#   ]
# }
# Successfully executed row Ultra Facial Cream SPF 30
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "facial_treatment_mask",
#       "brand": "SK-II",
#       "name": "Facial Treatment Mask",
#       "price": "135",
#       "rank": "4.4",
#       "size": "10 sheets",
#       "category": "Face Mask"
#     },
#     {
#       "label": "Ingredient",
#       "id": "water",
#       "name": "Water"
#     },
#     {
#       "label": "Ingredient",
#       "id": "saccharomycopsis_ferment_filtrate",
#       "name": "Saccharomycopsis Ferment Filtrate",
#       "alias": "Pitera"
#     },
#     {
#       "label": "Ingredient",
#       "id": "butylene_glycol",
#       "name": "Butylene Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "xanthan_gum",
#       "name": "Xanthan Gum"
#     },
#     {
#       "label": "Ingredient",
#       "id": "sodium_salicylate",
#       "name": "Sodium Salicylate"
#     },
#     {
#       "label": "Ingredient",
#       "id": "methylparaben",
#       "name": "Methylparaben"
#     },
#     {
#       "label": "Ingredient",
#       "id": "disodium_edta",
#       "name": "Disodium EDTA"
#     },
#     {
#       "label": "Benefit",
#       "id": "brightens_skin",
#       "name": "Brightens skin"
#     },
#     {
#       "label": "Benefit",
#       "id": "hydrates_skin",
#       "name": "Hydrates skin"
#     },
#     {
#       "label": "Benefit",
#       "id": "rejuvenates_skin",
#       "name": "Rejuvenates skin"
#     }
#   ],
#   "relationships": [
#     "facial_treatment_mask|CONTAINS_INGREDIENT|water",
#     "facial_treatment_mask|CONTAINS_INGREDIENT|saccharomycopsis_ferment_filtrate",
#     "facial_treatment_mask|CONTAINS_INGREDIENT|butylene_glycol",
#     "facial_treatment_mask|CONTAINS_INGREDIENT|xanthan_gum",
#     "facial_treatment_mask|CONTAINS_INGREDIENT|sodium_salicylate",
#     "facial_treatment_mask|CONTAINS_INGREDIENT|methylparaben",
#     "facial_treatment_mask|CONTAINS_INGREDIENT|disodium_edta",
#     "facial_treatment_mask|PROVIDES_BENEFIT|brightens_skin",
#     "facial_treatment_mask|PROVIDES_BENEFIT|hydrates_skin",
#     "facial_treatment_mask|PROVIDES_BENEFIT|rejuvenates_skin"
#   ]
# }
# Successfully executed row Facial Treatment Mask
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "overnight_miracle_mask",
#       "brand": "SK-II",
#       "name": "Overnight Miracle Mask",
#       "price": "105",
#       "rank": "3.8",
#       "size": "2.8 oz (80g)",
#       "category": "Face Mask"
#     },
#     {
#       "label": "Ingredient",
#       "id": "galactomyces_ferment_filtrate",
#       "name": "Galactomyces Ferment Filtrate"
#     },
#     {
#       "label": "Ingredient",
#       "id": "water",
#       "name": "Water"
#     },
#     {
#       "label": "Ingredient",
#       "id": "glycerin",
#       "name": "Glycerin"
#     },
#     {
#       "label": "Ingredient",
#       "id": "butylene_glycol",
#       "name": "Butylene Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "xylitol",
#       "name": "Xylitol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "dipropylene_glycol",
#       "name": "Dipropylene Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "cyclopentasiloxane",
#       "name": "Cyclopentasiloxane"
#     },
#     {
#       "label": "Ingredient",
#       "id": "dimethicone",
#       "name": "Dimethicone"
#     },
#     {
#       "label": "Ingredient",
#       "id": "fragrance",
#       "name": "Fragrance"
#     },
#     {
#       "label": "Ingredient",
#       "id": "aluminum_starch_octenylsuccinate",
#       "name": "Aluminum Starch Octenylsuccinate"
#     },
#     {
#       "label": "Benefit",
#       "id": "replenish_moisture",
#       "name": "Replenish Moisture"
#     },
#     {
#       "label": "Benefit",
#       "id": "smooth_texture",
#       "name": "Smooth Texture"
#     },
#     {
#       "label": "Benefit",
#       "id": "restore_skin_radiance",
#       "name": "Restore Skin's Natural Radiance"
#     }
#   ],
#   "relationships": [
#     "overnight_miracle_mask|CONTAINS_INGREDIENT|galactomyces_ferment_filtrate",
#     "overnight_miracle_mask|CONTAINS_INGREDIENT|water",
#     "overnight_miracle_mask|CONTAINS_INGREDIENT|glycerin",
#     "overnight_miracle_mask|CONTAINS_INGREDIENT|butylene_glycol",
#     "overnight_miracle_mask|CONTAINS_INGREDIENT|xylitol",
#     "overnight_miracle_mask|CONTAINS_INGREDIENT|dipropylene_glycol",
#     "overnight_miracle_mask|CONTAINS_INGREDIENT|cyclopentasiloxane",
#     "overnight_miracle_mask|CONTAINS_INGREDIENT|dimethicone",
#     "overnight_miracle_mask|CONTAINS_INGREDIENT|fragrance",
#     "overnight_miracle_mask|CONTAINS_INGREDIENT|aluminum_starch_octenylsuccinate",
#     "overnight_miracle_mask|PROVIDES_BENEFIT|replenish_moisture",
#     "overnight_miracle_mask|PROVIDES_BENEFIT|smooth_texture",
#     "overnight_miracle_mask|PROVIDES_BENEFIT|restore_skin_radiance"
#   ]
# }
# Successfully executed row Overnight Miracle Mask
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "calendula_aloe_soothing_hydration_mask",
#       "brand": "KIEHL'S SINCE 1851",
#       "name": "Calendula & Aloe Soothing Hydration Mask",
#       "price": "45",
#       "rank": "4.0",
#       "size": "3.4 oz (100ml)",
#       "category": "Face Mask"
#     },
#     {
#       "label": "Ingredient",
#       "id": "water",
#       "name": "Water"
#     },
#     {
#       "label": "Ingredient",
#       "id": "glycerin",
#       "name": "Glycerin"
#     },
#     {
#       "label": "Ingredient",
#       "id": "aloe_barbadensis_leaf_juice",
#       "name": "Aloe Barbadensis Leaf Juice"
#     },
#     {
#       "label": "Ingredient",
#       "id": "calendula_officinalis_flower",
#       "name": "Calendula Officinalis Flower"
#     },
#     {
#       "label": "Benefit",
#       "id": "soothing",
#       "name": "Soothing"
#     },
#     {
#       "label": "Benefit",
#       "id": "hydration",
#       "name": "Hydration"
#     },
#     {
#       "label": "Benefit",
#       "id": "calming",
#       "name": "Calming"
#     },
#     {
#       "label": "Benefit",
#       "id": "replenishing",
#       "name": "Replenishing"
#     },
#     {
#       "label": "SkinConcern",
#       "id": "dry_skin",
#       "name": "Dry Skin"
#     },
#     {
#       "label": "SkinConcern",
#       "id": "sensitive_skin",
#       "name": "Sensitive Skin"
#     },
#     {
#       "label": "SkinConcern",
#       "id": "irritated_skin",
#       "name": "Irritated Skin"
#     }
#   ],
#   "relationships": [
#     "calendula_aloe_soothing_hydration_mask|CONTAINS_INGREDIENT|water",
#     "calendula_aloe_soothing_hydration_mask|CONTAINS_INGREDIENT|glycerin",
#     "calendula_aloe_soothing_hydration_mask|CONTAINS_INGREDIENT|aloe_barbadensis_leaf_juice",
#     "calendula_aloe_soothing_hydration_mask|CONTAINS_INGREDIENT|calendula_officinalis_flower",
#     "calendula_aloe_soothing_hydration_mask|PROVIDES_BENEFIT|soothing",
#     "calendula_aloe_soothing_hydration_mask|PROVIDES_BENEFIT|hydration",
#     "calendula_aloe_soothing_hydration_mask|PROVIDES_BENEFIT|calming",
#     "calendula_aloe_soothing_hydration_mask|PROVIDES_BENEFIT|replenishing",
#     "calendula_aloe_soothing_hydration_mask|ADDRESSES_CONCERN|dry_skin",
#     "calendula_aloe_soothing_hydration_mask|ADDRESSES_CONCERN|sensitive_skin",
#     "calendula_aloe_soothing_hydration_mask|ADDRESSES_CONCERN|irritated_skin"
#   ]
# }
# Successfully executed row Calendula & Aloe Soothing Hydration Mask
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "brightening_derm_revival_mask",
#       "brand": "SK-II",
#       "name": "Brightening Derm Revival Mask",
#       "price": "170",
#       "rank": "4.5",
#       "size": "10 sheets",
#       "category": "Face Mask"
#     },
#     {
#       "label": "Ingredient",
#       "id": "water",
#       "name": "Water"
#     },
#     {
#       "label": "Ingredient",
#       "id": "galactomyces_ferment_filtrate_pitera",
#       "name": "Galactomyces Ferment Filtrate (Pitera)"
#     },
#     {
#       "label": "Ingredient",
#       "id": "butylene_glycol",
#       "name": "Butylene Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "niacinamide",
#       "name": "Niacinamide"
#     },
#     {
#       "label": "Ingredient",
#       "id": "glycerin",
#       "name": "Glycerin"
#     },
#     {
#       "label": "Ingredient",
#       "id": "pentylene_glycol",
#       "name": "Pentylene Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "ascorbyl_glucoside",
#       "name": "Ascorbyl Glucoside"
#     },
#     {
#       "label": "Ingredient",
#       "id": "inositol",
#       "name": "Inositol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "acrylates_c10_30_alkyl_acrylate_crosspolymer",
#       "name": "Acrylates/C10-30 Alkyl Acrylate Crosspolymer"
#     },
#     {
#       "label": "Ingredient",
#       "id": "hexapeptide_11",
#       "name": "Hexapeptide-11"
#     },
#     {
#       "label": "Benefit",
#       "id": "brightening",
#       "name": "Brightening"
#     },
#     {
#       "label": "Benefit",
#       "id": "even_skin_tone",
#       "name": "Even Skin Tone"
#     },
#     {
#       "label": "Benefit",
#       "id": "diminish_appearance_of_dark_spots",
#       "name": "Diminish Appearance of Dark Spots"
#     },
#     {
#       "label": "Benefit",
#       "id": "reduce_dullness",
#       "name": "Reduce Dullness"
#     },
#     {
#       "label": "Benefit",
#       "id": "radiant_complexion",
#       "name": "Radiant Complexion"
#     }
#   ],
#   "relationships": [
#     "brightening_derm_revival_mask|CONTAINS_INGREDIENT|water",
#     "brightening_derm_revival_mask|CONTAINS_INGREDIENT|galactomyces_ferment_filtrate_pitera",
#     "brightening_derm_revival_mask|CONTAINS_INGREDIENT|butylene_glycol",
#     "brightening_derm_revival_mask|CONTAINS_INGREDIENT|niacinamide",
#     "brightening_derm_revival_mask|CONTAINS_INGREDIENT|glycerin",
#     "brightening_derm_revival_mask|CONTAINS_INGREDIENT|pentylene_glycol",
#     "brightening_derm_revival_mask|CONTAINS_INGREDIENT|ascorbyl_glucoside",
#     "brightening_derm_revival_mask|CONTAINS_INGREDIENT|inositol",
#     "brightening_derm_revival_mask|CONTAINS_INGREDIENT|acrylates_c10_30_alkyl_acrylate_crosspolymer",
#     "brightening_derm_revival_mask|CONTAINS_INGREDIENT|hexapeptide_11",
#     "brightening_derm_revival_mask|HAS_BENEFIT|brightening",
#     "brightening_derm_revival_mask|HAS_BENEFIT|even_skin_tone",
#     "brightening_derm_revival_mask|HAS_BENEFIT|diminish_appearance_of_dark_spots",
#     "brightening_derm_revival_mask|HAS_BENEFIT|reduce_dullness",
#     "brightening_derm_revival_mask|HAS_BENEFIT|radiant_complexion"
#   ]
# }
# Successfully executed row Brightening Derm Revival Mask
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "ginger_leaf_hibiscus_firming_mask",
#       "brand": "KIEHL'S SINCE 1851",
#       "name": "Ginger Leaf & Hibiscus Firming Mask",
#       "price": "54",
#       "rank": "4.4",
#       "size": "3.5 oz (100ml)",
#       "category": "Face Mask"
#     },
#     {
#       "label": "Ingredient",
#       "id": "water",
#       "name": "Water"
#     },
#     {
#       "label": "Ingredient",
#       "id": "pvp",
#       "name": "PVP"
#     },
#     {
#       "label": "Ingredient",
#       "id": "propanediol",
#       "name": "Propanediol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "behenyl_alcohol",
#       "name": "Behenyl Alcohol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "caprylic_capric_triglyceride",
#       "name": "Caprylic/Capric Triglyceride"
#     },
#     {
#       "label": "Ingredient",
#       "id": "isoamyl_laurate",
#       "name": "Isoamyl Laurate"
#     },
#     {
#       "label": "Ingredient",
#       "id": "mangifera_indica_seed_butter",
#       "name": "Mangifera Indica Seed Butter/Mango Seed Butter"
#     },
#     {
#       "label": "Ingredient",
#       "id": "butyrospermum_parkii_butter",
#       "name": "Butyrospermum Parkii Butter/Shea Butter"
#     },
#     {
#       "label": "Ingredient",
#       "id": "butyrospermum_parkii_oil",
#       "name": "Butyrospermum Parkii Oil/Shea Oil"
#     },
#     {
#       "label": "Ingredient",
#       "id": "pullulan",
#       "name": "Pullulan"
#     },
#     {
#       "label": "Benefit",
#       "id": "improve_skin_elasticity",
#       "name": "Improve skin's elasticity"
#     },
#     {
#       "label": "Benefit",
#       "id": "reduce_fine_lines_and_wrinkles",
#       "name": "Reduce the appearance of fine lines and wrinkles"
#     }
#   ],
#   "relationships": [
#     "ginger_leaf_hibiscus_firming_mask|CONTAINS_INGREDIENT|water",
#     "ginger_leaf_hibiscus_firming_mask|CONTAINS_INGREDIENT|pvp",
#     "ginger_leaf_hibiscus_firming_mask|CONTAINS_INGREDIENT|propanediol",
#     "ginger_leaf_hibiscus_firming_mask|CONTAINS_INGREDIENT|behenyl_alcohol",
#     "ginger_leaf_hibiscus_firming_mask|CONTAINS_INGREDIENT|caprylic_capric_triglyceride",
#     "ginger_leaf_hibiscus_firming_mask|CONTAINS_INGREDIENT|isoamyl_laurate",
#     "ginger_leaf_hibiscus_firming_mask|CONTAINS_INGREDIENT|mangifera_indica_seed_butter",
#     "ginger_leaf_hibiscus_firming_mask|CONTAINS_INGREDIENT|butyrospermum_parkii_butter",
#     "ginger_leaf_hibiscus_firming_mask|CONTAINS_INGREDIENT|butyrospermum_parkii_oil",
#     "ginger_leaf_hibiscus_firming_mask|CONTAINS_INGREDIENT|pullulan",
#     "ginger_leaf_hibiscus_firming_mask|PROVIDES_BENEFIT|improve_skin_elasticity",
#     "ginger_leaf_hibiscus_firming_mask|PROVIDES_BENEFIT|reduce_fine_lines_and_wrinkles"
#   ]
# }
# Successfully executed row Ginger Leaf & Hibiscus Firming Mask
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "treatment_lotion_hydrating_mask",
#       "brand": "LA MER",
#       "name": "Treatment Lotion Hydrating Mask",
#       "price": "150",
#       "rank": "4.1",
#       "size": "6 sheets",
#       "category": "Face Mask"
#     },
#     {
#       "label": "Ingredient",
#       "id": "water",
#       "name": "Water"
#     },
#     {
#       "label": "Ingredient",
#       "id": "algae_seaweed_extract",
#       "name": "Algae (Seaweed) Extract"
#     },
#     {
#       "label": "Ingredient",
#       "id": "glycerin",
#       "name": "Glycerin"
#     },
#     {
#       "label": "Ingredient",
#       "id": "methyl_gluceth_20",
#       "name": "Methyl Gluceth-20"
#     },
#     {
#       "label": "Ingredient",
#       "id": "bis_peg_18_methyl_ether_dimethyl_silane",
#       "name": "Bis-Peg-18 Methyl EtherDimethyl Silane"
#     },
#     {
#       "label": "Ingredient",
#       "id": "butylene_glycol",
#       "name": "Butylene Glycol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "hypnea_musciformis_algae_extract",
#       "name": "Hypnea Musciformis (Algae) Extract"
#     },
#     {
#       "label": "Ingredient",
#       "id": "sucrose",
#       "name": "Sucrose"
#     },
#     {
#       "label": "Ingredient",
#       "id": "propanediol",
#       "name": "Propanediol"
#     },
#     {
#       "label": "Ingredient",
#       "id": "sesamum_indicum_sesame_seed_oil",
#       "name": "Sesamum Indicum (Sesame) Seed Oil"
#     },
#     {
#       "label": "Benefit",
#       "id": "intense_moisture",
#       "name": "Intense Moisture"
#     },
#     {
#       "label": "Benefit",
#       "id": "skin_renewal",
#       "name": "Skin Renewal"
#     },
#     {
#       "label": "Brand",
#       "id": "la_mer",
#       "name": "LA MER"
#     }
#   ],
#   "relationships": [
#     "treatment_lotion_hydrating_mask|HAS_INGREDIENT|water",
#     "treatment_lotion_hydrating_mask|HAS_INGREDIENT|algae_seaweed_extract",
#     "treatment_lotion_hydrating_mask|HAS_INGREDIENT|glycerin",
#     "treatment_lotion_hydrating_mask|HAS_INGREDIENT|methyl_gluceth_20",
#     "treatment_lotion_hydrating_mask|HAS_INGREDIENT|bis_peg_18_methyl_ether_dimethyl_silane",
#     "treatment_lotion_hydrating_mask|HAS_INGREDIENT|butylene_glycol",
#     "treatment_lotion_hydrating_mask|HAS_INGREDIENT|hypnea_musciformis_algae_extract",
#     "treatment_lotion_hydrating_mask|HAS_INGREDIENT|sucrose",
#     "treatment_lotion_hydrating_mask|HAS_INGREDIENT|propanediol",
#     "treatment_lotion_hydrating_mask|HAS_INGREDIENT|sesamum_indicum_sesame_seed_oil",
#     "treatment_lotion_hydrating_mask|HAS_BENEFIT|intense_moisture",
#     "treatment_lotion_hydrating_mask|HAS_BENEFIT|skin_renewal",
#     "treatment_lotion_hydrating_mask|BRAND|la_mer"
#   ]
# }
# Successfully executed row Treatment Lotion Hydrating Mask
# --- Extracted JSON Block ---
# {
#   "entities": [
#     {
#       "label": "Product",
#       "id": "advanced_night_repair_concentrated_recovery_eye_mask",
#       "brand": "ESTÉE LAUDER",
# ...
# Running: MATCH (a:Product {id: "advanced_night_repair_concentrated_recovery_eye_mask"}) MATCH (b:Ingredient {id: "glycereth_26"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_concentrated_recovery_eye_mask"}) MATCH (b:Ingredient {id: "cladosiphon_okamuranus_extract"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_concentrated_recovery_eye_mask"}) MATCH (b:Ingredient {id: "silybum_marianum_extract"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_concentrated_recovery_eye_mask"}) MATCH (b:Ingredient {id: "echinacea_purpurea_extract"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_concentrated_recovery_eye_mask"}) MATCH (b:Benefit {id: "reduces_puffiness"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_concentrated_recovery_eye_mask"}) MATCH (b:Benefit {id: "reduces_fine_lines"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_concentrated_recovery_eye_mask"}) MATCH (b:Benefit {id: "reduces_dark_circles"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_concentrated_recovery_eye_mask"}) MATCH (b:Benefit {id: "refreshed_appearance"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "cilantro_orange_extract_pollutant_defending_mask"}) MATCH (b:Ingredient {id: "water"}) MERGE (a)-[:HAS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "cilantro_orange_extract_pollutant_defending_mask"}) MATCH (b:Ingredient {id: "propanediol"}) MERGE (a)-[:HAS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "cilantro_orange_extract_pollutant_defending_mask"}) MATCH (b:Ingredient {id: "shea_butter"}) MERGE (a)-[:HAS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "cilantro_orange_extract_pollutant_defending_mask"}) MATCH (b:Ingredient {id: "glycerin"}) MERGE (a)-[:HAS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "cilantro_orange_extract_pollutant_defending_mask"}) MATCH (b:Ingredient {id: "cetearyl_alcohol"}) MERGE (a)-[:HAS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "cilantro_orange_extract_pollutant_defending_mask"}) MATCH (b:Ingredient {id: "arginine"}) MERGE (a)-[:HAS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "cilantro_orange_extract_pollutant_defending_mask"}) MATCH (b:Ingredient {id: "glyceryl_stearate"}) MERGE (a)-[:HAS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "cilantro_orange_extract_pollutant_defending_mask"}) MATCH (b:Ingredient {id: "apricot_kernel_oil"}) MERGE (a)-[:HAS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "cilantro_orange_extract_pollutant_defending_mask"}) MATCH (b:Ingredient {id: "lauroyl_lysine"}) MERGE (a)-[:HAS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "cilantro_orange_extract_pollutant_defending_mask"}) MATCH (b:Ingredient {id: "vaccinium_myrtillus_fruit_extract"}) MERGE (a)-[:HAS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "cilantro_orange_extract_pollutant_defending_mask"}) MATCH (b:Brand {id: "kiehl_s_since_1851"}) MERGE (a)-[:HAS_BRAND]->(b)
# Running: MATCH (a:Product {id: "cilantro_orange_extract_pollutant_defending_mask"}) MATCH (b:Benefit {id: "defend_against_environmental_pollutants"}) MERGE (a)-[:HAS_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "cilantro_orange_extract_pollutant_defending_mask"}) MATCH (b:Benefit {id: "remove_impurities"}) MERGE (a)-[:HAS_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "cilantro_orange_extract_pollutant_defending_mask"}) MATCH (b:Benefit {id: "clearer_healthier_looking_skin"}) MERGE (a)-[:HAS_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_concentrate_matrix"}) MATCH (b:Ingredient {id: "water"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_concentrate_matrix"}) MATCH (b:Ingredient {id: "dimethicone"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_concentrate_matrix"}) MATCH (b:Ingredient {id: "isohexadecane"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_concentrate_matrix"}) MATCH (b:Ingredient {id: "glycerin"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_concentrate_matrix"}) MATCH (b:Ingredient {id: "butylene_glycol"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_concentrate_matrix"}) MATCH (b:Ingredient {id: "bis_peg_18_methyl_ether_dimethyl_silane"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_concentrate_matrix"}) MATCH (b:Ingredient {id: "peg_10_dimethicone"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_concentrate_matrix"}) MATCH (b:Ingredient {id: "disteardimonium_hectorite"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_concentrate_matrix"}) MATCH (b:Ingredient {id: "isopropyl_isostearate"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_concentrate_matrix"}) MATCH (b:Ingredient {id: "ppg_15_stearyl_ether"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_concentrate_matrix"}) MATCH (b:Benefit {id: "reduces_puffiness"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_concentrate_matrix"}) MATCH (b:Benefit {id: "reduces_fine_lines"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_concentrate_matrix"}) MATCH (b:Benefit {id: "reduces_crepiness"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_concentrate_matrix"}) MATCH (b:Benefit {id: "lifted_appearance"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_concentrate_matrix"}) MATCH (b:Technology {id: "matrix_technology"}) MERGE (a)-[:USES_TECHNOLOGY]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_serum_synchronized_complex_ii"}) MATCH (b:Ingredient {id: "water"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_serum_synchronized_complex_ii"}) MATCH (b:Ingredient {id: "bifida_ferment_lysate"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_serum_synchronized_complex_ii"}) MATCH (b:Ingredient {id: "caprylic_capric_triglyceride"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_serum_synchronized_complex_ii"}) MATCH (b:Ingredient {id: "dimethicone"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_serum_synchronized_complex_ii"}) MATCH (b:Ingredient {id: "nylon_12"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_serum_synchronized_complex_ii"}) MATCH (b:Ingredient {id: "cetyl_ricinoleate"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_serum_synchronized_complex_ii"}) MATCH (b:Ingredient {id: "propanediol"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_serum_synchronized_complex_ii"}) MATCH (b:Ingredient {id: "bis_peg_18_methyl_ether_dimethyl_silane"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_serum_synchronized_complex_ii"}) MATCH (b:Ingredient {id: "glycerin"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_serum_synchronized_complex_ii"}) MATCH (b:Ingredient {id: "trehalose"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_serum_synchronized_complex_ii"}) MATCH (b:Benefit {id: "reduce_appearance_of_fine_lines"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_serum_synchronized_complex_ii"}) MATCH (b:Benefit {id: "reduce_appearance_of_wrinkles"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_serum_synchronized_complex_ii"}) MATCH (b:Benefit {id: "reduce_appearance_of_dark_circles"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_serum_synchronized_complex_ii"}) MATCH (b:Benefit {id: "hydrating"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "advanced_night_repair_eye_serum_synchronized_complex_ii"}) MATCH (b:Benefit {id: "fortifying_delicate_skin"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "youth_dose_eye_treatment"}) MATCH (b:Ingredient {id: "water"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "youth_dose_eye_treatment"}) MATCH (b:Ingredient {id: "dimethicone"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "youth_dose_eye_treatment"}) MATCH (b:Ingredient {id: "glycerin"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "youth_dose_eye_treatment"}) MATCH (b:Ingredient {id: "pro_retinol"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "youth_dose_eye_treatment"}) MATCH (b:Ingredient {id: "vitamin_c"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "youth_dose_eye_treatment"}) MATCH (b:Ingredient {id: "grape_seed_extract"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "youth_dose_eye_treatment"}) MATCH (b:Benefit {id: "brightening"}) MERGE (a)-[:HAS_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "youth_dose_eye_treatment"}) MATCH (b:Benefit {id: "smoothing"}) MERGE (a)-[:HAS_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "youth_dose_eye_treatment"}) MATCH (b:Benefit {id: "diminish_dark_circles"}) MERGE (a)-[:HAS_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "youth_dose_eye_treatment"}) MATCH (b:Benefit {id: "reduce_fine_lines"}) MERGE (a)-[:HAS_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "youth_dose_eye_treatment"}) MATCH (b:Benefit {id: "reduce_puffiness"}) MERGE (a)-[:HAS_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Brand {id: "kiehl_s_since_1851"}) MERGE (a)-[:BRAND]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "propylene_glycol"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "cyclopentasiloxane"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "ascorbic_acid"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "glycerin"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "cetyl_peg_ppg_10_1_dimethicone"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "dimethicone_crosspolymer"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "aqua_water"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "lauroyl_lysine"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "acrylates_copolymer"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "escin"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "silica_dimethyl_silylate"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "adenosine"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "n_hydroxysuccinimide"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "palmitoyl_oligopeptide"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "chrysin"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Ingredient {id: "palmitoyl_tetrapeptide_7"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Benefit {id: "reduce_appearance_of_lines"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Benefit {id: "reduce_dark_circles"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "powerful_strength_line_reducing_eye_brightening_concentrate"}) MATCH (b:Benefit {id: "brighter_looking_eyes"}) MERGE (a)-[:PROVIDES_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "clearly_corrective_dark_circle_perfector"}) MATCH (b:Ingredient {id: "water"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "clearly_corrective_dark_circle_perfector"}) MATCH (b:Ingredient {id: "cyclopentasiloxane"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "clearly_corrective_dark_circle_perfector"}) MATCH (b:Ingredient {id: "isododecane"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "clearly_corrective_dark_circle_perfector"}) MATCH (b:Ingredient {id: "dimethicone"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "clearly_corrective_dark_circle_perfector"}) MATCH (b:Ingredient {id: "glycerin"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "clearly_corrective_dark_circle_perfector"}) MATCH (b:Ingredient {id: "nylon_12"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "clearly_corrective_dark_circle_perfector"}) MATCH (b:Ingredient {id: "peg_9_polydimethylsiloxyethyl_dimethicone"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "clearly_corrective_dark_circle_perfector"}) MATCH (b:Ingredient {id: "butylene_glycol"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "clearly_corrective_dark_circle_perfector"}) MATCH (b:Ingredient {id: "cyclohexasiloxane"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "clearly_corrective_dark_circle_perfector"}) MATCH (b:Ingredient {id: "silica"}) MERGE (a)-[:CONTAINS_INGREDIENT]->(b)
# Running: MATCH (a:Product {id: "clearly_corrective_dark_circle_perfector"}) MATCH (b:Benefit {id: "color_correcting"}) MERGE (a)-[:HAS_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "clearly_corrective_dark_circle_perfector"}) MATCH (b:Benefit {id: "conceals_dark_circles"}) MERGE (a)-[:HAS_BENEFIT]->(b)
# Running: MATCH (a:Product {id: "clearly_corrective_dark_circle_perfector"}) MATCH (b:Benefit {id: "improves_appearance_over_time"}) MERGE (a)-[:HAS_BENEFIT]->(b)

# %%
def execute_cypher_from_file(filepath):
    try:
        with open(filepath, 'r') as file:
            cypher_statements = [line.strip() for line in file if line.strip()]

        print(f"Found {len(cypher_statements)} Cypher statements to execute")

        failed_statements = []
        with gds.session() as session:
            for i, stmt in enumerate(cypher_statements, 1):
                try:
                    print(f"Executing statement {i} of {len(cypher_statements)}")
                    session.run(stmt)
                except Exception as e:
                    print(f"Error executing statement {i}: {e}")
                    failed_statements.append((stmt, str(e)))

        success_count = len(cypher_statements) - len(failed_statements)
        print(f"\nExecution complete: {success_count}/{len(cypher_statements)} successful")

        if failed_statements:
            with open("failed_statements.txt", "w") as f:
                for stmt, error in failed_statements:
                    f.write(f"Statement: {stmt}\nError: {error}\n\n")
            print("Failed statements written to 'failed_statements.txt'")

    except FileNotFoundError:
        print(f"Error: Could not find file '{filepath}'")
    except Exception as e:
        print(f"Unexpected error: {e}")
    finally:
        gds.close()

# %%
execute_cypher_from_file("cyphers.txt")
# Out:
# Found 657 Cypher statements to execute
# Executing statement 1 of 657
# Executing statement 2 of 657
# Executing statement 3 of 657
# Executing statement 4 of 657
# Executing statement 5 of 657
# Executing statement 6 of 657
# Executing statement 7 of 657
# Executing statement 8 of 657
# Executing statement 9 of 657
# Executing statement 10 of 657
# Executing statement 11 of 657
# Executing statement 12 of 657
# Executing statement 13 of 657
# Executing statement 14 of 657
# Executing statement 15 of 657
# Executing statement 16 of 657
# Executing statement 17 of 657
# Executing statement 18 of 657
# Executing statement 19 of 657
# Executing statement 20 of 657
# Executing statement 21 of 657
# Executing statement 22 of 657
# Executing statement 23 of 657
# Executing statement 24 of 657
# Executing statement 25 of 657
# Executing statement 26 of 657
# Executing statement 27 of 657
# Executing statement 28 of 657
# Executing statement 29 of 657
# Executing statement 30 of 657
# Executing statement 31 of 657
# Executing statement 32 of 657
# Executing statement 33 of 657
# Executing statement 34 of 657
# Executing statement 35 of 657
# Executing statement 36 of 657
# Executing statement 37 of 657
# Executing statement 38 of 657
# Executing statement 39 of 657
# Executing statement 40 of 657
# Executing statement 41 of 657
# Executing statement 42 of 657
# Executing statement 43 of 657
# Executing statement 44 of 657
# Executing statement 45 of 657
# Executing statement 46 of 657
# Executing statement 47 of 657
# Executing statement 48 of 657
# Executing statement 49 of 657
# Executing statement 50 of 657
# Executing statement 51 of 657
# Executing statement 52 of 657
# Executing statement 53 of 657
# Executing statement 54 of 657
# Executing statement 55 of 657
# Executing statement 56 of 657
# Executing statement 57 of 657
# Executing statement 58 of 657
# Executing statement 59 of 657
# Executing statement 60 of 657
# Executing statement 61 of 657
# Executing statement 62 of 657
# Executing statement 63 of 657
# Executing statement 64 of 657
# Executing statement 65 of 657
# Executing statement 66 of 657
# Executing statement 67 of 657
# Executing statement 68 of 657
# Executing statement 69 of 657
# Executing statement 70 of 657
# Executing statement 71 of 657
# Executing statement 72 of 657
# Executing statement 73 of 657
# Executing statement 74 of 657
# Executing statement 75 of 657
# Executing statement 76 of 657
# Executing statement 77 of 657
# Executing statement 78 of 657
# Executing statement 79 of 657
# Executing statement 80 of 657
# Executing statement 81 of 657
# Executing statement 82 of 657
# Executing statement 83 of 657
# Executing statement 84 of 657
# Executing statement 85 of 657
# Executing statement 86 of 657
# Executing statement 87 of 657
# Executing statement 88 of 657
# Executing statement 89 of 657
# Executing statement 90 of 657
# Executing statement 91 of 657
# Executing statement 92 of 657
# Executing statement 93 of 657
# Executing statement 94 of 657
# Executing statement 95 of 657
# Executing statement 96 of 657
# Executing statement 97 of 657
# Executing statement 98 of 657
# Executing statement 99 of 657
# Executing statement 100 of 657
# Executing statement 101 of 657
# Executing statement 102 of 657
# Executing statement 103 of 657
# Executing statement 104 of 657
# Executing statement 105 of 657
# Executing statement 106 of 657
# Executing statement 107 of 657
# Executing statement 108 of 657
# Executing statement 109 of 657
# Executing statement 110 of 657
# Executing statement 111 of 657
# Executing statement 112 of 657
# Executing statement 113 of 657
# Executing statement 114 of 657
# Executing statement 115 of 657
# Executing statement 116 of 657
# Executing statement 117 of 657
# Executing statement 118 of 657
# Executing statement 119 of 657
# Executing statement 120 of 657
# Executing statement 121 of 657
# Executing statement 122 of 657
# Executing statement 123 of 657
# Executing statement 124 of 657
# Executing statement 125 of 657
# Executing statement 126 of 657
# Executing statement 127 of 657
# Executing statement 128 of 657
# Executing statement 129 of 657
# Executing statement 130 of 657
# Executing statement 131 of 657
# Executing statement 132 of 657
# Executing statement 133 of 657
# Executing statement 134 of 657
# Executing statement 135 of 657
# Executing statement 136 of 657
# Executing statement 137 of 657
# Executing statement 138 of 657
# Executing statement 139 of 657
# Executing statement 140 of 657
# Executing statement 141 of 657
# Executing statement 142 of 657
# Executing statement 143 of 657
# Executing statement 144 of 657
# Executing statement 145 of 657
# Executing statement 146 of 657
# Executing statement 147 of 657
# Executing statement 148 of 657
# Executing statement 149 of 657
# Executing statement 150 of 657
# Executing statement 151 of 657
# Executing statement 152 of 657
# Executing statement 153 of 657
# Executing statement 154 of 657
# Executing statement 155 of 657
# Executing statement 156 of 657
# Executing statement 157 of 657
# Executing statement 158 of 657
# Executing statement 159 of 657
# Executing statement 160 of 657
# Executing statement 161 of 657
# Executing statement 162 of 657
# Executing statement 163 of 657
# Executing statement 164 of 657
# Executing statement 165 of 657
# Executing statement 166 of 657
# Executing statement 167 of 657
# Executing statement 168 of 657
# Executing statement 169 of 657
# Executing statement 170 of 657
# Executing statement 171 of 657
# Executing statement 172 of 657
# Executing statement 173 of 657
# Executing statement 174 of 657
# Executing statement 175 of 657
# Executing statement 176 of 657
# Executing statement 177 of 657
# Executing statement 178 of 657
# Executing statement 179 of 657
# Executing statement 180 of 657
# Executing statement 181 of 657
# Executing statement 182 of 657
# Executing statement 183 of 657
# Executing statement 184 of 657
# Executing statement 185 of 657
# Executing statement 186 of 657
# Executing statement 187 of 657
# Executing statement 188 of 657
# Executing statement 189 of 657
# Executing statement 190 of 657
# Executing statement 191 of 657
# Executing statement 192 of 657
# Executing statement 193 of 657
# Executing statement 194 of 657
# Executing statement 195 of 657
# Executing statement 196 of 657
# Executing statement 197 of 657
# Executing statement 198 of 657
# Executing statement 199 of 657
# Executing statement 200 of 657
# Executing statement 201 of 657
# Executing statement 202 of 657
# Executing statement 203 of 657
# Executing statement 204 of 657
# Executing statement 205 of 657
# Executing statement 206 of 657
# Executing statement 207 of 657
# Executing statement 208 of 657
# Executing statement 209 of 657
# Executing statement 210 of 657
# Executing statement 211 of 657
# Executing statement 212 of 657
# Executing statement 213 of 657
# Executing statement 214 of 657
# Executing statement 215 of 657
# Executing statement 216 of 657
# Executing statement 217 of 657
# Executing statement 218 of 657
# Executing statement 219 of 657
# Executing statement 220 of 657
# Executing statement 221 of 657
# Executing statement 222 of 657
# Executing statement 223 of 657
# Executing statement 224 of 657
# Executing statement 225 of 657
# Executing statement 226 of 657
# Executing statement 227 of 657
# Executing statement 228 of 657
# Executing statement 229 of 657
# Executing statement 230 of 657
# Executing statement 231 of 657
# Executing statement 232 of 657
# Executing statement 233 of 657
# Executing statement 234 of 657
# Executing statement 235 of 657
# Executing statement 236 of 657
# Executing statement 237 of 657
# Executing statement 238 of 657
# Executing statement 239 of 657
# Executing statement 240 of 657
# Executing statement 241 of 657
# Executing statement 242 of 657
# Executing statement 243 of 657
# Executing statement 244 of 657
# Executing statement 245 of 657
# Executing statement 246 of 657
# Executing statement 247 of 657
# Executing statement 248 of 657
# Executing statement 249 of 657
# Executing statement 250 of 657
# Executing statement 251 of 657
# Executing statement 252 of 657
# Executing statement 253 of 657
# Executing statement 254 of 657
# Executing statement 255 of 657
# Executing statement 256 of 657
# Executing statement 257 of 657
# Executing statement 258 of 657
# Executing statement 259 of 657
# Executing statement 260 of 657
# Executing statement 261 of 657
# Executing statement 262 of 657
# Executing statement 263 of 657
# Executing statement 264 of 657
# Executing statement 265 of 657
# Executing statement 266 of 657
# Executing statement 267 of 657
# Executing statement 268 of 657
# Executing statement 269 of 657
# Executing statement 270 of 657
# Executing statement 271 of 657
# Executing statement 272 of 657
# Executing statement 273 of 657
# Executing statement 274 of 657
# Executing statement 275 of 657
# Executing statement 276 of 657
# Executing statement 277 of 657
# Executing statement 278 of 657
# Executing statement 279 of 657
# Executing statement 280 of 657
# Executing statement 281 of 657
# Executing statement 282 of 657
# Executing statement 283 of 657
# Executing statement 284 of 657
# Executing statement 285 of 657
# Executing statement 286 of 657
# Executing statement 287 of 657
# Executing statement 288 of 657
# Executing statement 289 of 657
# Executing statement 290 of 657
# Executing statement 291 of 657
# Executing statement 292 of 657
# Executing statement 293 of 657
# Executing statement 294 of 657
# Executing statement 295 of 657
# Executing statement 296 of 657
# Executing statement 297 of 657
# Executing statement 298 of 657
# Executing statement 299 of 657
# Executing statement 300 of 657
# Executing statement 301 of 657
# Executing statement 302 of 657
# Executing statement 303 of 657
# Executing statement 304 of 657
# Executing statement 305 of 657
# Executing statement 306 of 657
# Executing statement 307 of 657
# Executing statement 308 of 657
# Executing statement 309 of 657
# Executing statement 310 of 657
# Executing statement 311 of 657
# Executing statement 312 of 657
# Executing statement 313 of 657
# Executing statement 314 of 657
# Executing statement 315 of 657
# Executing statement 316 of 657
# Executing statement 317 of 657
# Executing statement 318 of 657
# Executing statement 319 of 657
# Executing statement 320 of 657
# Executing statement 321 of 657
# Executing statement 322 of 657
# Executing statement 323 of 657
# Executing statement 324 of 657
# Executing statement 325 of 657
# Executing statement 326 of 657
# Executing statement 327 of 657
# Executing statement 328 of 657
# Executing statement 329 of 657
# Executing statement 330 of 657
# Executing statement 331 of 657
# Executing statement 332 of 657
# Executing statement 333 of 657
# Executing statement 334 of 657
# Executing statement 335 of 657
# Executing statement 336 of 657
# Executing statement 337 of 657
# Executing statement 338 of 657
# Executing statement 339 of 657
# Executing statement 340 of 657
# Executing statement 341 of 657
# Executing statement 342 of 657
# Executing statement 343 of 657
# Executing statement 344 of 657
# Executing statement 345 of 657
# Executing statement 346 of 657
# Executing statement 347 of 657
# Executing statement 348 of 657
# Executing statement 349 of 657
# Executing statement 350 of 657
# Executing statement 351 of 657
# Executing statement 352 of 657
# Executing statement 353 of 657
# Executing statement 354 of 657
# Executing statement 355 of 657
# Executing statement 356 of 657
# Executing statement 357 of 657
# Executing statement 358 of 657
# Executing statement 359 of 657
# Executing statement 360 of 657
# Executing statement 361 of 657
# Executing statement 362 of 657
# Executing statement 363 of 657
# Executing statement 364 of 657
# Executing statement 365 of 657
# Executing statement 366 of 657
# Executing statement 367 of 657
# Executing statement 368 of 657
# Executing statement 369 of 657
# Executing statement 370 of 657
# Executing statement 371 of 657
# Executing statement 372 of 657
# Executing statement 373 of 657
# Executing statement 374 of 657
# Executing statement 375 of 657
# Executing statement 376 of 657
# Executing statement 377 of 657
# Executing statement 378 of 657
# Executing statement 379 of 657
# Executing statement 380 of 657
# Executing statement 381 of 657
# Executing statement 382 of 657
# Executing statement 383 of 657
# Executing statement 384 of 657
# Executing statement 385 of 657
# Executing statement 386 of 657
# Executing statement 387 of 657
# Executing statement 388 of 657
# Executing statement 389 of 657
# Executing statement 390 of 657
# Executing statement 391 of 657
# Executing statement 392 of 657
# Executing statement 393 of 657
# Executing statement 394 of 657
# Executing statement 395 of 657
# Executing statement 396 of 657
# Executing statement 397 of 657
# Executing statement 398 of 657
# Executing statement 399 of 657
# Executing statement 400 of 657
# Executing statement 401 of 657
# Executing statement 402 of 657
# Executing statement 403 of 657
# Executing statement 404 of 657
# Executing statement 405 of 657
# Executing statement 406 of 657
# Executing statement 407 of 657
# Executing statement 408 of 657
# Executing statement 409 of 657
# Executing statement 410 of 657
# Executing statement 411 of 657
# Executing statement 412 of 657
# Executing statement 413 of 657
# Executing statement 414 of 657
# Executing statement 415 of 657
# Executing statement 416 of 657
# Executing statement 417 of 657
# Executing statement 418 of 657
# Executing statement 419 of 657
# Executing statement 420 of 657
# Executing statement 421 of 657
# Executing statement 422 of 657
# Executing statement 423 of 657
# Executing statement 424 of 657
# Executing statement 425 of 657
# Executing statement 426 of 657
# Executing statement 427 of 657
# Executing statement 428 of 657
# Executing statement 429 of 657
# Executing statement 430 of 657
# Executing statement 431 of 657
# Executing statement 432 of 657
# Executing statement 433 of 657
# Executing statement 434 of 657
# Executing statement 435 of 657
# Executing statement 436 of 657
# Executing statement 437 of 657
# Executing statement 438 of 657
# Executing statement 439 of 657
# Executing statement 440 of 657
# Executing statement 441 of 657
# Executing statement 442 of 657
# Executing statement 443 of 657
# Executing statement 444 of 657
# Executing statement 445 of 657
# Executing statement 446 of 657
# Executing statement 447 of 657
# Executing statement 448 of 657
# Executing statement 449 of 657
# Executing statement 450 of 657
# Executing statement 451 of 657
# Executing statement 452 of 657
# Executing statement 453 of 657
# Executing statement 454 of 657
# Executing statement 455 of 657
# Executing statement 456 of 657
# Executing statement 457 of 657
# Executing statement 458 of 657
# Executing statement 459 of 657
# Executing statement 460 of 657
# Executing statement 461 of 657
# Executing statement 462 of 657
# Executing statement 463 of 657
# Executing statement 464 of 657
# Executing statement 465 of 657
# Executing statement 466 of 657
# Executing statement 467 of 657
# Executing statement 468 of 657
# Executing statement 469 of 657
# Executing statement 470 of 657
# Executing statement 471 of 657
# Executing statement 472 of 657
# Executing statement 473 of 657
# Executing statement 474 of 657
# Executing statement 475 of 657
# Executing statement 476 of 657
# Executing statement 477 of 657
# Executing statement 478 of 657
# Executing statement 479 of 657
# Executing statement 480 of 657
# Executing statement 481 of 657
# Executing statement 482 of 657
# Executing statement 483 of 657
# Executing statement 484 of 657
# Executing statement 485 of 657
# Executing statement 486 of 657
# Executing statement 487 of 657
# Executing statement 488 of 657
# Executing statement 489 of 657
# Executing statement 490 of 657
# Executing statement 491 of 657
# Executing statement 492 of 657
# Executing statement 493 of 657
# Executing statement 494 of 657
# Executing statement 495 of 657
# Executing statement 496 of 657
# Executing statement 497 of 657
# Executing statement 498 of 657
# Executing statement 499 of 657
# Executing statement 500 of 657
# Executing statement 501 of 657
# Executing statement 502 of 657
# Executing statement 503 of 657
# Executing statement 504 of 657
# Executing statement 505 of 657
# Executing statement 506 of 657
# Executing statement 507 of 657
# Executing statement 508 of 657
# Executing statement 509 of 657
# Executing statement 510 of 657
# Executing statement 511 of 657
# Executing statement 512 of 657
# Executing statement 513 of 657
# Executing statement 514 of 657
# Executing statement 515 of 657
# Executing statement 516 of 657
# Executing statement 517 of 657
# Executing statement 518 of 657
# Executing statement 519 of 657
# Executing statement 520 of 657
# Executing statement 521 of 657
# Executing statement 522 of 657
# Executing statement 523 of 657
# Executing statement 524 of 657
# Executing statement 525 of 657
# Executing statement 526 of 657
# Executing statement 527 of 657
# Executing statement 528 of 657
# Executing statement 529 of 657
# Executing statement 530 of 657
# Executing statement 531 of 657
# Executing statement 532 of 657
# Executing statement 533 of 657
# Executing statement 534 of 657
# Executing statement 535 of 657
# Executing statement 536 of 657
# Executing statement 537 of 657
# Executing statement 538 of 657
# Executing statement 539 of 657
# Executing statement 540 of 657
# Executing statement 541 of 657
# Executing statement 542 of 657
# Executing statement 543 of 657
# Executing statement 544 of 657
# Executing statement 545 of 657
# Executing statement 546 of 657
# Executing statement 547 of 657
# Executing statement 548 of 657
# Executing statement 549 of 657
# Executing statement 550 of 657
# Executing statement 551 of 657
# Executing statement 552 of 657
# Executing statement 553 of 657
# Executing statement 554 of 657
# Executing statement 555 of 657
# Executing statement 556 of 657
# Executing statement 557 of 657
# Executing statement 558 of 657
# Executing statement 559 of 657
# Executing statement 560 of 657
# Executing statement 561 of 657
# Executing statement 562 of 657
# Executing statement 563 of 657
# Executing statement 564 of 657
# Executing statement 565 of 657
# Executing statement 566 of 657
# Executing statement 567 of 657
# Executing statement 568 of 657
# Executing statement 569 of 657
# Executing statement 570 of 657
# Executing statement 571 of 657
# Executing statement 572 of 657
# Executing statement 573 of 657
# Executing statement 574 of 657
# Executing statement 575 of 657
# Executing statement 576 of 657
# Executing statement 577 of 657
# Executing statement 578 of 657
# Executing statement 579 of 657
# Executing statement 580 of 657
# Executing statement 581 of 657
# Executing statement 582 of 657
# Executing statement 583 of 657
# Executing statement 584 of 657
# Executing statement 585 of 657
# Executing statement 586 of 657
# Executing statement 587 of 657
# Executing statement 588 of 657
# Executing statement 589 of 657
# Executing statement 590 of 657
# Executing statement 591 of 657
# Executing statement 592 of 657
# Executing statement 593 of 657
# Executing statement 594 of 657
# Executing statement 595 of 657
# Executing statement 596 of 657
# Executing statement 597 of 657
# Executing statement 598 of 657
# Executing statement 599 of 657
# Executing statement 600 of 657
# Executing statement 601 of 657
# Executing statement 602 of 657
# Executing statement 603 of 657
# Executing statement 604 of 657
# Executing statement 605 of 657
# Executing statement 606 of 657
# Executing statement 607 of 657
# Executing statement 608 of 657
# Executing statement 609 of 657
# Executing statement 610 of 657
# Executing statement 611 of 657
# Executing statement 612 of 657
# Executing statement 613 of 657
# Executing statement 614 of 657
# Executing statement 615 of 657
# Executing statement 616 of 657
# Executing statement 617 of 657
# Executing statement 618 of 657
# Executing statement 619 of 657
# Executing statement 620 of 657
# Executing statement 621 of 657
# Executing statement 622 of 657
# Executing statement 623 of 657
# Executing statement 624 of 657
# Executing statement 625 of 657
# Executing statement 626 of 657
# Executing statement 627 of 657
# Executing statement 628 of 657
# Executing statement 629 of 657
# Executing statement 630 of 657
# Executing statement 631 of 657
# Executing statement 632 of 657
# Executing statement 633 of 657
# Executing statement 634 of 657
# Executing statement 635 of 657
# Executing statement 636 of 657
# Executing statement 637 of 657
# Executing statement 638 of 657
# Executing statement 639 of 657
# Executing statement 640 of 657
# Executing statement 641 of 657
# Executing statement 642 of 657
# Executing statement 643 of 657
# Executing statement 644 of 657
# Executing statement 645 of 657
# Executing statement 646 of 657
# Executing statement 647 of 657
# Executing statement 648 of 657
# Executing statement 649 of 657
# Executing statement 650 of 657
# Executing statement 651 of 657
# Executing statement 652 of 657
# Executing statement 653 of 657
# Executing statement 654 of 657
# Executing statement 655 of 657
# Executing statement 656 of 657
# Executing statement 657 of 657
#
# Execution complete: 657/657 successful

# %%
df = pd.read_csv(raw_csv_path, quotechar='"', escapechar='\\', engine='python', encoding='utf-8-sig')
df = df.fillna("").head(2)
df
# Out:
#    Unnamed: 0        Label   Brand                         Name  Price  Rank  \
# 0           1  Moisturizer   SK-II     Facial Treatment Essence    179   4.1
# 1           3  Moisturizer  LA MER  The Moisturizing Soft Cream    175   3.8
#
#                                          Ingredients  \
# 0  Galactomyces Ferment Filtrate (Pitera), Butyle...
# 1  Algae (Seaweed) Extract, Cyclopentasiloxane, P...
#
#                             For Skin Type            Size  \
# 0  ['Dry', 'Normal', 'Oily', 'Sensitive']  5.0 oz (150ml)
# 1  ['Dry', 'Normal', 'Oily', 'Sensitive']   1.0 oz (30ml)
#
#                                          Description
# 0  A signature essence with 90% Pitera, a bio-ing...
# 1  A silky-soft cream powered by miracle broth th...
